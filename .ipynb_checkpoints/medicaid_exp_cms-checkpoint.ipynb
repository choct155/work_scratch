# %% [markdown]
# # Medicaid Data by State from CMS (1997-2014)

# %% [markdown]
# In an attempt to develop a proxy for Medicaid program generosity (see **`mcaid_by_state`**), it became clear that NIPA data conflicted with other sources.  Specifically, some states had wildly different data from the information presented by [KFF](http://kff.org/medicaid/state-indicator/total-medicaid-spending/#), which is based on Form CM-64 data reported by states to CMS.  To some extent, we have limited recourse.  Before 1997, we NIPA is the only consolidate source of Medicaid spending by state.  However, CMS has made data available from 1997 on.
#
# In this Notebook, we will liberate the data between 1997 and 2014 from the sadistic shackles that CMS has chosen to store it, otherwise known as Excel.

# %%
#Data Management
import numpy as np
import pandas as pd
from pandas import Series, DataFrame
from openpyxl import *

#Visualization
import seaborn as sb

# %pylab inline

plt.rcParams['axes.edgecolor']='k'
plt.rcParams['axes.linewidth']=1
plt.rcParams['axes.facecolor']=(1,1,1,0)
plt.rcParams['grid.color']='k'
plt.rcParams['grid.linestyle']=':'
plt.rcParams['grid.linewidth']=0.3
# Out:
# Populating the interactive namespace from numpy and matplotlib
# C:\Users\marvinw\AppData\Local\Continuum\Anaconda\lib\site-packages\matplotlib\__init__.py:872: UserWarning: axes.color_cycle is deprecated and replaced with axes.prop_cycle; please use the latter.
#   warnings.warn(self.msg_depr % (key, alt_key))

# %% [markdown]
# The [data in question](https://www.medicaid.gov/medicaid-chip-program-information/by-topics/financing-and-reimbursement/expenditure-reports-mbes-cbes.html) are housed in four workbooks with irregular temporal coverage and formatting.  The formatting in particular means we will not be able to rely on a general function to handle all of it.  However, we should be fairly consistent within the workbook, so some room for programmatic efficiency is available.

# %% [markdown]
# ## 1997-2001

# %% [markdown]
# We can start by loading the first notebook and grabbing the sheet names.

# %%
#Establish data location
data_dir='O:/Analyst/Marvin/Medicaid/'

#Read in data
fmr97=load_workbook(data_dir+'FMR1997through2001.xlsx')

#Create container to hold sheet objects
fmr97_dict={}

#Capture sheet objects
for sheet in fmr97.get_sheet_names():
    fmr97_dict.update({int(sheet[-4:]):fmr97.get_sheet_by_name(sheet)})
    
fmr97_dict[1997]
# Out:
# <Worksheet "FMR1997">

# %% [markdown]
# Once we have a sheet, we can query its contents in a couple ways...

# %%
print fmr97_dict[1998]['A1'].value
print fmr97_dict[1998].cell(row=1,column=1).value
# Out:
# Medicaid Finanacial Management Report
# Medicaid Finanacial Management Report

# %% [markdown]
# Visual inspection suggests that there are a few pieces of information we want to collect.
#
# 1. The state name;
# 2. Total Medicaid expenditure;
# 3. The federal share of Medicaid expenditure; and,
# 4. The state share of Medicaid expenditure.
#
# Each observation in our final set will carry these pieces of information, in addition to the year (which is constant within sheet).  Total expenditure (and the shares) must be aggregated over two data within-state data points:
#
# 1. `Total Net Expenditures`
# 2. `C-Total Net`
#
# To allocate these expenditures, we will rely on position.  The values of net expenditures that follow Alaska, but precede Alabama (presumably ordered by postal code) will be allocated to Alaska.  Therefore, we need a function that will identify a state name as the start of an observation, capture the cumulative expenditures as we move down through the rows, and then simultaneously close out that observation while opening a new observation upon encountering the next state name.
#
# The `cell()` method enables us to iteratively run across the sheet via simple loops.  We can capture the start position of each observation, and then the positions of the relevant values for that observation.  Capturing the rows with the data is easy, because the tags don't change.  The states, on the other hand, are not marked by some common concept ID.  We need to test membership in a list of state names to identify them.  Let's grab that state info first.

# %%
#Read in mapping
st_map=pd.read_csv('https://raw.githubusercontent.com/jasonong/List-of-US-States/master/states.csv')

#Convert to dict
st_dict=dict(zip(st_map['State'],st_map['Abbreviation']))

#Include DC
st_dict.update({'District of Columbia':'DC',
                'Dist. Of Col.':'DC',
                'DC':'DC',
                'Amer. Samoa':'AS',
                'American Samoa':'AS',
                'N. Mariana Islands':'NMI',
                'Guam':'GU',
                'Mass. Blind':'MB'})

# %% [markdown]
# ...and now the positions.

# %%
#Create a container for state positions
state_pos=[]

#For each row...
for i in range(int(fmr97_dict[1998].max_row)):
    #...if the cell value is in the list of states...
    if fmr97_dict[1998].cell(row=i+1,column=1).value in st_dict.keys():
        #...capture the position and the cell value
        state_pos.append((i+1,fmr97_dict[1998].cell(row=i+1,column=1).value))
        
#Create a container for data positions
data_pos=[]

#For each row...
for i in range(int(fmr97_dict[1998].max_row)):
    #...if the cell value is in the list of states...
    if fmr97_dict[1998].cell(row=i+1,column=1).value in ['Total Net Expenditures','C-Total Net']:
        #...capture the position and the cell value
        data_pos.append((i+1,fmr97_dict[1998].cell(row=i+1,column=1).value))
        

for i in range(len(state_pos))[1:]:
    if state_pos[i][0]-state_pos[i-1][0]!=86:
        print state_pos[i],state_pos[i-1]
# Out:
# (1209, u'Hawaii') (1037, u'Georgia')
# (2069, u'Maryland') (1897, u'Massachusetts')
# (3789, u'Rhode Island') (3617, u'Pennsylvania')
# (4477, u'Vermont') (4305, u'Virginia')

# %%
fmr97_dict[1998].cell(row=pos_i,column=[2,3]).value
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-62-63daeabfd8d4> in <module>()
# ----> 1 fmr97_dict[1998].cell(row=pos_i,column=[2,3]).value
#
# C:\Users\marvinw\AppData\Local\Continuum\Anaconda\lib\site-packages\openpyxl\worksheet\worksheet.pyc in cell(self, coordinate, row, column, value)
#     348                 raise InsufficientCoordinatesException(msg)
#     349             else:
# --> 350                 column = get_column_letter(column)
#     351                 coordinate = '%s%s' % (column, row)
#     352         else:
#
# C:\Users\marvinw\AppData\Local\Continuum\Anaconda\lib\site-packages\openpyxl\utils\__init__.pyc in get_column_letter(idx)
#      96     """
#      97     try:
# ---> 98         return _STRING_COL_CACHE[idx]
#      99     except KeyError:
#     100         raise ValueError("Invalid column index {0}".format(idx))
#
# TypeError: unhashable type: 'list'

# %%
exp_components=['Total Net Expenditures','C-Total Net']

state_tmp={}
for pos in state_pos:
    print '***',pos,'***'
    pos_tmp={}
    pos_i=pos[0]
    for component in exp_components:
#         'Seeking '+component
        while fmr97_dict[1998].cell(row=pos_i,column=1).value!=component and pos_i<20000:
            pos_i+=1
            if fmr97_dict[1998].cell(row=pos_i,column=1).value==component:
                pos_tmp.update({component:fmr97_dict[1998].cell(row=pos_i,column=2).value})
                break
#         print 'Eureka! ',fmr97_dict[1998].cell(row=pos_i,column=1).value
    state_tmp.update({pos[1]:pos_tmp})
        
state_tmp
# Out:
# *** (5, u'Alaska') ***
# *** (91, u'Alabama') ***
# *** (177, u'Arkansas') ***
# *** (263, u'Amer. Samoa') ***
# *** (349, u'Arizona') ***
# *** (435, u'California') ***
# *** (521, u'N. Mariana Islands') ***
# *** (607, u'Colorado') ***
# *** (693, u'Connecticut') ***
# *** (779, u'Dist. Of Col.') ***
# *** (865, u'Delaware') ***
# *** (951, u'Florida') ***
# *** (1037, u'Georgia') ***
# *** (1209, u'Hawaii') ***
# *** (1295, u'Iowa') ***
# *** (1381, u'Idaho') ***
# *** (1467, u'Illinois') ***
# *** (1553, u'Indiana') ***
# *** (1639, u'Kansas') ***
# *** (1725, u'Kentucky') ***
# *** (1811, u'Louisiana') ***
# *** (1897, u'Massachusetts') ***
# *** (2069, u'Maryland') ***
# *** (2155, u'Maine') ***
# *** (2241, u'Michigan') ***
# *** (2327, u'Minnesota') ***
# *** (2413, u'Missouri') ***
# *** (2499, u'Mississippi') ***
# *** (2585, u'Montana') ***
# *** (2671, u'North Carolina') ***
# *** (2757, u'North Dakota') ***
# *** (2843, u'Nebraska') ***
# *** (2929, u'New Hampshire') ***
# *** (3015, u'New Jersey') ***
# *** (3101, u'New Mexico') ***
# *** (3187, u'Nevada') ***
# *** (3273, u'New York') ***
# *** (3359, u'Ohio') ***
# *** (3445, u'Oklahoma') ***
# *** (3531, u'Oregon') ***
# *** (3617, u'Pennsylvania') ***
# *** (3789, u'Rhode Island') ***
# *** (3875, u'South Carolina') ***
# *** (3961, u'South Dakota') ***
# *** (4047, u'Tennessee') ***
# *** (4133, u'Texas') ***
# *** (4219, u'Utah') ***
# *** (4305, u'Virginia') ***
# *** (4477, u'Vermont') ***
# *** (4563, u'Washington') ***
# *** (4649, u'Wisconsin') ***
# *** (4735, u'West Virginia') ***
# *** (4821, u'Wyoming') ***
# {u'Alabama': {'C-Total Net': 2788912, 'Total Net Expenditures': 2324140936L},
#  u'Alaska': {'C-Total Net': 0, 'Total Net Expenditures': 362921319},
#  u'Amer. Samoa': {'C-Total Net': 0, 'Total Net Expenditures': 11602064},
#  u'Arizona': {'C-Total Net': 0, 'Total Net Expenditures': 1861049085},
#  u'Arkansas': {'C-Total Net': 0, 'Total Net Expenditures': 1406248828},
#  u'California': {'C-Total Net': 1186963,
#   'Total Net Expenditures': 18332289798L},
#  u'Colorado': {'C-Total Net': 0, 'Total Net Expenditures': 1604443241},
#  u'Connecticut': {'C-Total Net': 0, 'Total Net Expenditures': 2831673760L},
#  u'Delaware': {'C-Total Net': 0, 'Total Net Expenditures': 414170166},
#  u'Dist. Of Col.': {'C-Total Net': 0, 'Total Net Expenditures': 865522374},
#  u'Florida': {'C-Total Net': 6454111, 'Total Net Expenditures': 6364304715L},
#  u'Georgia': {'C-Total Net': 0, 'Total Net Expenditures': 3487596382L},
#  u'Hawaii': {'C-Total Net': 0, 'Total Net Expenditures': 586017229},
#  u'Idaho': {'C-Total Net': 1562098, 'Total Net Expenditures': 409757770},
#  u'Illinois': {'C-Total Net': 9356392, 'Total Net Expenditures': 6513232918L},
#  u'Indiana': {'C-Total Net': 0, 'Total Net Expenditures': 2576711795L},
#  u'Iowa': {'C-Total Net': 339491, 'Total Net Expenditures': 1346708657},
#  u'Kansas': {'C-Total Net': 0, 'Total Net Expenditures': 1092755554},
#  u'Kentucky': {'C-Total Net': 0, 'Total Net Expenditures': 2595560522L},
#  u'Louisiana': {'C-Total Net': 0, 'Total Net Expenditures': 3174393283L},
#  u'Maine': {'C-Total Net': 0, 'Total Net Expenditures': 1078129415},
#  u'Maryland': {'C-Total Net': 969704, 'Total Net Expenditures': 2577612749L},
#  u'Massachusetts': {'C-Total Net': 0, 'Total Net Expenditures': 5495566575L},
#  u'Michigan': {'C-Total Net': 974415, 'Total Net Expenditures': 5739450008L},
#  u'Minnesota': {'C-Total Net': 0, 'Total Net Expenditures': 2989023193L},
#  u'Mississippi': {'C-Total Net': 0, 'Total Net Expenditures': 1655616964},
#  u'Missouri': {'C-Total Net': 0, 'Total Net Expenditures': 3282989240L},
#  u'Montana': {'C-Total Net': 0, 'Total Net Expenditures': 390677296},
#  u'N. Mariana Islands': {'C-Total Net': 910050,
#   'Total Net Expenditures': 5803967},
#  u'Nebraska': {'C-Total Net': 6623, 'Total Net Expenditures': 845789092},
#  u'Nevada': {'C-Total Net': 0, 'Total Net Expenditures': 512705956},
#  u'New Hampshire': {'C-Total Net': 0, 'Total Net Expenditures': 742733205},
#  u'New Jersey': {'C-Total Net': 4532479,
#   'Total Net Expenditures': 5435965101L},
#  u'New Mexico': {'C-Total Net': 0, 'Total Net Expenditures': 1009763654},
#  u'New York': {'C-Total Net': 0, 'Total Net Expenditures': 27249782989L},
#  u'North Carolina': {'C-Total Net': 0, 'Total Net Expenditures': 4547778029L},
#  u'North Dakota': {'C-Total Net': 0, 'Total Net Expenditures': 330511776},
#  u'Ohio': {'C-Total Net': 12218003, 'Total Net Expenditures': 6657514427L},
#  u'Oklahoma': {'C-Total Net': 0, 'Total Net Expenditures': 1340387625},
#  u'Oregon': {'C-Total Net': 0, 'Total Net Expenditures': 1709202554},
#  u'Pennsylvania': {'C-Total Net': 0, 'Total Net Expenditures': 8505650827L},
#  u'Rhode Island': {'C-Total Net': 0, 'Total Net Expenditures': 959907699},
#  u'South Carolina': {'C-Total Net': 31846762,
#   'Total Net Expenditures': 2260021439L},
#  u'South Dakota': {'C-Total Net': 60479, 'Total Net Expenditures': 355565985},
#  u'Tennessee': {'C-Total Net': 0, 'Total Net Expenditures': 3973329340L},
#  u'Texas': {'C-Total Net': 1732882, 'Total Net Expenditures': 9775199709L},
#  u'Utah': {'C-Total Net': 0, 'Total Net Expenditures': 676933365},
#  u'Vermont': {'C-Total Net': 0, 'Total Net Expenditures': 397345688},
#  u'Virginia': {'C-Total Net': 0, 'Total Net Expenditures': 2343757339L},
#  u'Washington': {'C-Total Net': 0, 'Total Net Expenditures': 3315723592L},
#  u'West Virginia': {'C-Total Net': 4222, 'Total Net Expenditures': 1359804168},
#  u'Wisconsin': {'C-Total Net': 0, 'Total Net Expenditures': 2758480825L},
#  u'Wyoming': {'C-Total Net': 0, 'Total Net Expenditures': 197439227}}

# %%
data_pos
# Out:
# [(54, u'Total Net Expenditures'),
#  (89, u'C-Total Net'),
#  (140, u'Total Net Expenditures'),
#  (175, u'C-Total Net'),
#  (226, u'Total Net Expenditures'),
#  (261, u'C-Total Net'),
#  (312, u'Total Net Expenditures'),
#  (347, u'C-Total Net'),
#  (398, u'Total Net Expenditures'),
#  (433, u'C-Total Net'),
#  (484, u'Total Net Expenditures'),
#  (519, u'C-Total Net'),
#  (570, u'Total Net Expenditures'),
#  (605, u'C-Total Net'),
#  (656, u'Total Net Expenditures'),
#  (691, u'C-Total Net'),
#  (742, u'Total Net Expenditures'),
#  (777, u'C-Total Net'),
#  (828, u'Total Net Expenditures'),
#  (863, u'C-Total Net'),
#  (914, u'Total Net Expenditures'),
#  (949, u'C-Total Net'),
#  (1000, u'Total Net Expenditures'),
#  (1035, u'C-Total Net'),
#  (1086, u'Total Net Expenditures'),
#  (1121, u'C-Total Net'),
#  (1172, u'Total Net Expenditures'),
#  (1207, u'C-Total Net'),
#  (1258, u'Total Net Expenditures'),
#  (1293, u'C-Total Net'),
#  (1344, u'Total Net Expenditures'),
#  (1379, u'C-Total Net'),
#  (1430, u'Total Net Expenditures'),
#  (1465, u'C-Total Net'),
#  (1516, u'Total Net Expenditures'),
#  (1551, u'C-Total Net'),
#  (1602, u'Total Net Expenditures'),
#  (1637, u'C-Total Net'),
#  (1688, u'Total Net Expenditures'),
#  (1723, u'C-Total Net'),
#  (1774, u'Total Net Expenditures'),
#  (1809, u'C-Total Net'),
#  (1860, u'Total Net Expenditures'),
#  (1895, u'C-Total Net'),
#  (1946, u'Total Net Expenditures'),
#  (1981, u'C-Total Net'),
#  (2032, u'Total Net Expenditures'),
#  (2067, u'C-Total Net'),
#  (2118, u'Total Net Expenditures'),
#  (2153, u'C-Total Net'),
#  (2204, u'Total Net Expenditures'),
#  (2239, u'C-Total Net'),
#  (2290, u'Total Net Expenditures'),
#  (2325, u'C-Total Net'),
#  (2376, u'Total Net Expenditures'),
#  (2411, u'C-Total Net'),
#  (2462, u'Total Net Expenditures'),
#  (2497, u'C-Total Net'),
#  (2548, u'Total Net Expenditures'),
#  (2583, u'C-Total Net'),
#  (2634, u'Total Net Expenditures'),
#  (2669, u'C-Total Net'),
#  (2720, u'Total Net Expenditures'),
#  (2755, u'C-Total Net'),
#  (2806, u'Total Net Expenditures'),
#  (2841, u'C-Total Net'),
#  (2892, u'Total Net Expenditures'),
#  (2927, u'C-Total Net'),
#  (2978, u'Total Net Expenditures'),
#  (3013, u'C-Total Net'),
#  (3064, u'Total Net Expenditures'),
#  (3099, u'C-Total Net'),
#  (3150, u'Total Net Expenditures'),
#  (3185, u'C-Total Net'),
#  (3236, u'Total Net Expenditures'),
#  (3271, u'C-Total Net'),
#  (3322, u'Total Net Expenditures'),
#  (3357, u'C-Total Net'),
#  (3408, u'Total Net Expenditures'),
#  (3443, u'C-Total Net'),
#  (3494, u'Total Net Expenditures'),
#  (3529, u'C-Total Net'),
#  (3580, u'Total Net Expenditures'),
#  (3615, u'C-Total Net'),
#  (3666, u'Total Net Expenditures'),
#  (3701, u'C-Total Net'),
#  (3752, u'Total Net Expenditures'),
#  (3787, u'C-Total Net'),
#  (3838, u'Total Net Expenditures'),
#  (3873, u'C-Total Net'),
#  (3924, u'Total Net Expenditures'),
#  (3959, u'C-Total Net'),
#  (4010, u'Total Net Expenditures'),
#  (4045, u'C-Total Net'),
#  (4096, u'Total Net Expenditures'),
#  (4131, u'C-Total Net'),
#  (4182, u'Total Net Expenditures'),
#  (4217, u'C-Total Net'),
#  (4268, u'Total Net Expenditures'),
#  (4303, u'C-Total Net'),
#  (4354, u'Total Net Expenditures'),
#  (4389, u'C-Total Net'),
#  (4440, u'Total Net Expenditures'),
#  (4475, u'C-Total Net'),
#  (4526, u'Total Net Expenditures'),
#  (4561, u'C-Total Net'),
#  (4612, u'Total Net Expenditures'),
#  (4647, u'C-Total Net'),
#  (4698, u'Total Net Expenditures'),
#  (4733, u'C-Total Net'),
#  (4784, u'Total Net Expenditures'),
#  (4819, u'C-Total Net'),
#  (4870, u'Total Net Expenditures'),
#  (4905, u'C-Total Net'),
#  (4956, u'Total Net Expenditures'),
#  (4991, u'C-Total Net')]

# %%
print fmr97_dict[1998].cell(row=1,column=1).value
print fmr97_dict[1998].max_row
print type(fmr97_dict[1998].max_row)
print type(int(fmr97_dict[1998].max_row))
for i in range(int(fmr97_dict[1998].max_row)):
    print (i+1,fmr97_dict[1998].cell(row=i+1,column=1).value)
# Out:
# Medicaid Finanacial Management Report
# 4991
# <type 'long'>
# <type 'int'>
# (1, u'Medicaid Finanacial Management Report')
# (2, u'FY 1998')
# (3, u'Net Services')
# (4, u'National')
# (5, u'Alaska')
# (6, None)
# (7, u'Medical Assistance Program')
# (8, u'Service Category')
# (9, None)
# (10, u'Inpatient Hospital - Reg. Payments')
# (11, u'Inpatient Hospital - DSH')
# (12, u'Mental Health Facility Services - Reg. Payments')
# (13, u'Mental Health Facility - DSH')
# (14, u'Nursing Facility Services')
# (15, u'Intermediate Care Facility - Public')
# (16, u'Intermediate Care - Private')
# (17, u"Physicians' Services")
# (18, u'Outpatient Hospital Services')
# (19, u'Prescribed Drugs')
# (20, u'Drug Rebate Offset - National')
# (21, u'Drug Rebate Offset - State Sidebar Agreement')
# (22, u'Dental Services')
# (23, u'Other Practicioners')
# (24, u'Clinic Services')
# (25, u'Laboratory/Radiological')
# (26, u'Home Health Services')
# (27, u'Sterilizations')
# (28, u'Abortions')
# (29, u'EPSDT Screening')
# (30, u'Rural Health')
# (31, u'Medicare - Part A')
# (32, u'Medicare - Part B')
# (33, u'120% - 134% Of Poverty')
# (34, u'135% - 175% Of Poverty')
# (35, u'Coinsurance')
# (36, u'Medicaid - MCO')
# (37, u'Medicaid - PHP')
# (38, u'Medicaid - Group Health')
# (39, u'Medicaid - Coinsurance')
# (40, u'Medicaid - Other')
# (41, u'Home and Community')
# (42, u'Home And Community - Disabled Elderly')
# (43, u'Community Supported')
# (44, u'All-Inclusive Care Elderly')
# (45, u'Personal Care Services')
# (46, u'Targeted Case Management')
# (47, u'Primary Care Case Management')
# (48, u'Hospice Benefits')
# (49, u'Emergency')
# (50, u'Federally-Qualified Health Center')
# (51, u'Other Care Services')
# (52, u'Balance')
# (53, u'Collections')
# (54, u'Total Net Expenditures')
# (55, u'C-Premiums: Up To 150% - Gross Premiums Paid')
# (56, u'C-Premiums: Up To 150% - Cost Sharing Offset')
# (57, u'C-Premiums: Over 150% - Gross Premiums Paid')
# (58, u'C-Premiums: Over 150% - Cost Sharing Offset')
# (59, u'C-Inpatient Hospital Services - Reg. Payments')
# (60, u'C-Inpatient Hospital Services - DSH')
# (61, u'C-Inpatient Mental Health - Reg. Payment')
# (62, u'C-Inpatient Mental Health - DSH')
# (63, u'C-Nursing Care Services')
# (64, u'C-Physician/Surgical')
# (65, u'C-Outpatient Hospital Services')
# (66, u'C-Outpatient Mental Health')
# (67, u'C-Prescribed Drugs')
# (68, u'C-Drug Rebate - National')
# (69, u'C-Drug Rebate - State')
# (70, u'C-Dental Services')
# (71, u'C-Vision Sevices')
# (72, u'C-Other Practitioners')
# (73, u'C-Clinic Services')
# (74, u'C-Therapy Services')
# (75, u'C-Laboratory/Radiological Services')
# (76, u'C-Medical Equipment')
# (77, u'C-Family Planning')
# (78, u'C-Abortions')
# (79, u'C-Screening Services')
# (80, u'C-Home Health')
# (81, u'C-Medicare Payments')
# (82, u'C-Home And Community')
# (83, u'C-Hospice')
# (84, u'C-Medical Transport')
# (85, u'C-Case Management')
# (86, u'C-Other Services')
# (87, u'C-Balance')
# (88, u'C-Collections')
# (89, u'C-Total Net')
# (90, None)
# (91, u'Alabama')
# (92, None)
# (93, u'Medical Assistance Program')
# (94, u'Service Category')
# (95, None)
# (96, u'Inpatient Hospital - Reg. Payments')
# (97, u'Inpatient Hospital - DSH')
# (98, u'Mental Health Facility Services - Reg. Payments')
# (99, u'Mental Health Facility - DSH')
# (100, u'Nursing Facility Services')
# (101, u'Intermediate Care Facility - Public')
# (102, u'Intermediate Care - Private')
# (103, u"Physicians' Services")
# (104, u'Outpatient Hospital Services')
# (105, u'Prescribed Drugs')
# (106, u'Drug Rebate Offset - National')
# (107, u'Drug Rebate Offset - State Sidebar Agreement')
# (108, u'Dental Services')
# (109, u'Other Practicioners')
# (110, u'Clinic Services')
# (111, u'Laboratory/Radiological')
# (112, u'Home Health Services')
# (113, u'Sterilizations')
# (114, u'Abortions')
# (115, u'EPSDT Screening')
# (116, u'Rural Health')
# (117, u'Medicare - Part A')
# (118, u'Medicare - Part B')
# (119, u'120% - 134% Of Poverty')
# (120, u'135% - 175% Of Poverty')
# (121, u'Coinsurance')
# (122, u'Medicaid - MCO')
# (123, u'Medicaid - PHP')
# (124, u'Medicaid - Group Health')
# (125, u'Medicaid - Coinsurance')
# (126, u'Medicaid - Other')
# (127, u'Home and Community')
# (128, u'Home And Community - Disabled Elderly')
# (129, u'Community Supported')
# (130, u'All-Inclusive Care Elderly')
# (131, u'Personal Care Services')
# (132, u'Targeted Case Management')
# (133, u'Primary Care Case Management')
# (134, u'Hospice Benefits')
# (135, u'Emergency')
# (136, u'Federally-Qualified Health Center')
# (137, u'Other Care Services')
# (138, u'Balance')
# (139, u'Collections')
# (140, u'Total Net Expenditures')
# (141, u'C-Premiums: Up To 150% - Gross Premiums Paid')
# (142, u'C-Premiums: Up To 150% - Cost Sharing Offset')
# (143, u'C-Premiums: Over 150% - Gross Premiums Paid')
# (144, u'C-Premiums: Over 150% - Cost Sharing Offset')
# (145, u'C-Inpatient Hospital Services - Reg. Payments')
# (146, u'C-Inpatient Hospital Services - DSH')
# (147, u'C-Inpatient Mental Health - Reg. Payment')
# (148, u'C-Inpatient Mental Health - DSH')
# (149, u'C-Nursing Care Services')
# (150, u'C-Physician/Surgical')
# (151, u'C-Outpatient Hospital Services')
# (152, u'C-Outpatient Mental Health')
# (153, u'C-Prescribed Drugs')
# (154, u'C-Drug Rebate - National')
# (155, u'C-Drug Rebate - State')
# (156, u'C-Dental Services')
# (157, u'C-Vision Sevices')
# (158, u'C-Other Practitioners')
# (159, u'C-Clinic Services')
# (160, u'C-Therapy Services')
# (161, u'C-Laboratory/Radiological Services')
# (162, u'C-Medical Equipment')
# (163, u'C-Family Planning')
# (164, u'C-Abortions')
# (165, u'C-Screening Services')
# (166, u'C-Home Health')
# (167, u'C-Medicare Payments')
# (168, u'C-Home And Community')
# (169, u'C-Hospice')
# (170, u'C-Medical Transport')
# (171, u'C-Case Management')
# (172, u'C-Other Services')
# (173, u'C-Balance')
# (174, u'C-Collections')
# (175, u'C-Total Net')
# (176, None)
# (177, u'Arkansas')
# (178, None)
# (179, u'Medical Assistance Program')
# (180, u'Service Category')
# (181, None)
# (182, u'Inpatient Hospital - Reg. Payments')
# (183, u'Inpatient Hospital - DSH')
# (184, u'Mental Health Facility Services - Reg. Payments')
# (185, u'Mental Health Facility - DSH')
# (186, u'Nursing Facility Services')
# (187, u'Intermediate Care Facility - Public')
# (188, u'Intermediate Care - Private')
# (189, u"Physicians' Services")
# (190, u'Outpatient Hospital Services')
# (191, u'Prescribed Drugs')
# (192, u'Drug Rebate Offset - National')
# (193, u'Drug Rebate Offset - State Sidebar Agreement')
# (194, u'Dental Services')
# (195, u'Other Practicioners')
# (196, u'Clinic Services')
# (197, u'Laboratory/Radiological')
# (198, u'Home Health Services')
# (199, u'Sterilizations')
# (200, u'Abortions')
# (201, u'EPSDT Screening')
# (202, u'Rural Health')
# (203, u'Medicare - Part A')
# (204, u'Medicare - Part B')
# (205, u'120% - 134% Of Poverty')
# (206, u'135% - 175% Of Poverty')
# (207, u'Coinsurance')
# (208, u'Medicaid - MCO')
# (209, u'Medicaid - PHP')
# (210, u'Medicaid - Group Health')
# (211, u'Medicaid - Coinsurance')
# (212, u'Medicaid - Other')
# (213, u'Home and Community')
# (214, u'Home And Community - Disabled Elderly')
# (215, u'Community Supported')
# (216, u'All-Inclusive Care Elderly')
# (217, u'Personal Care Services')
# (218, u'Targeted Case Management')
# (219, u'Primary Care Case Management')
# (220, u'Hospice Benefits')
# (221, u'Emergency')
# (222, u'Federally-Qualified Health Center')
# (223, u'Other Care Services')
# (224, u'Balance')
# (225, u'Collections')
# (226, u'Total Net Expenditures')
# (227, u'C-Premiums: Up To 150% - Gross Premiums Paid')
# (228, u'C-Premiums: Up To 150% - Cost Sharing Offset')
# (229, u'C-Premiums: Over 150% - Gross Premiums Paid')
# (230, u'C-Premiums: Over 150% - Cost Sharing Offset')
# (231, u'C-Inpatient Hospital Services - Reg. Payments')
# (232, u'C-Inpatient Hospital Services - DSH')
# (233, u'C-Inpatient Mental Health - Reg. Payment')
# (234, u'C-Inpatient Mental Health - DSH')
# (235, u'C-Nursing Care Services')
# (236, u'C-Physician/Surgical')
# (237, u'C-Outpatient Hospital Services')
# (238, u'C-Outpatient Mental Health')
# (239, u'C-Prescribed Drugs')
# (240, u'C-Drug Rebate - National')
# (241, u'C-Drug Rebate - State')
# (242, u'C-Dental Services')
# (243, u'C-Vision Sevices')
# (244, u'C-Other Practitioners')
# (245, u'C-Clinic Services')
# (246, u'C-Therapy Services')
# (247, u'C-Laboratory/Radiological Services')
# (248, u'C-Medical Equipment')
# (249, u'C-Family Planning')
# (250, u'C-Abortions')
# (251, u'C-Screening Services')
# (252, u'C-Home Health')
# (253, u'C-Medicare Payments')
# (254, u'C-Home And Community')
# (255, u'C-Hospice')
# (256, u'C-Medical Transport')
# (257, u'C-Case Management')
# (258, u'C-Other Services')
# (259, u'C-Balance')
# (260, u'C-Collections')
# (261, u'C-Total Net')
# (262, None)
# (263, u'Amer. Samoa')
# (264, None)
# (265, u'Medical Assistance Program')
# (266, u'Service Category')
# (267, None)
# (268, u'Inpatient Hospital - Reg. Payments')
# (269, u'Inpatient Hospital - DSH')
# (270, u'Mental Health Facility Services - Reg. Payments')
# (271, u'Mental Health Facility - DSH')
# (272, u'Nursing Facility Services')
# (273, u'Intermediate Care Facility - Public')
# (274, u'Intermediate Care - Private')
# (275, u"Physicians' Services")
# (276, u'Outpatient Hospital Services')
# (277, u'Prescribed Drugs')
# (278, u'Drug Rebate Offset - National')
# (279, u'Drug Rebate Offset - State Sidebar Agreement')
# (280, u'Dental Services')
# (281, u'Other Practicioners')
# (282, u'Clinic Services')
# (283, u'Laboratory/Radiological')
# (284, u'Home Health Services')
# (285, u'Sterilizations')
# (286, u'Abortions')
# (287, u'EPSDT Screening')
# (288, u'Rural Health')
# (289, u'Medicare - Part A')
# (290, u'Medicare - Part B')
# (291, u'120% - 134% Of Poverty')
# (292, u'135% - 175% Of Poverty')
# (293, u'Coinsurance')
# (294, u'Medicaid - MCO')
# (295, u'Medicaid - PHP')
# (296, u'Medicaid - Group Health')
# (297, u'Medicaid - Coinsurance')
# (298, u'Medicaid - Other')
# (299, u'Home and Community')
# (300, u'Home And Community - Disabled Elderly')
# (301, u'Community Supported')
# (302, u'All-Inclusive Care Elderly')
# (303, u'Personal Care Services')
# (304, u'Targeted Case Management')
# (305, u'Primary Care Case Management')
# (306, u'Hospice Benefits')
# (307, u'Emergency')
# (308, u'Federally-Qualified Health Center')
# (309, u'Other Care Services')
# (310, u'Balance')
# (311, u'Collections')
# (312, u'Total Net Expenditures')
# (313, u'C-Premiums: Up To 150% - Gross Premiums Paid')
# (314, u'C-Premiums: Up To 150% - Cost Sharing Offset')
# (315, u'C-Premiums: Over 150% - Gross Premiums Paid')
# (316, u'C-Premiums: Over 150% - Cost Sharing Offset')
# (317, u'C-Inpatient Hospital Services - Reg. Payments')
# (318, u'C-Inpatient Hospital Services - DSH')
# (319, u'C-Inpatient Mental Health - Reg. Payment')
# (320, u'C-Inpatient Mental Health - DSH')
# (321, u'C-Nursing Care Services')
# (322, u'C-Physician/Surgical')
# (323, u'C-Outpatient Hospital Services')
# (324, u'C-Outpatient Mental Health')
# (325, u'C-Prescribed Drugs')
# (326, u'C-Drug Rebate - National')
# (327, u'C-Drug Rebate - State')
# (328, u'C-Dental Services')
# (329, u'C-Vision Sevices')
# (330, u'C-Other Practitioners')
# (331, u'C-Clinic Services')
# (332, u'C-Therapy Services')
# (333, u'C-Laboratory/Radiological Services')
# (334, u'C-Medical Equipment')
# (335, u'C-Family Planning')
# (336, u'C-Abortions')
# (337, u'C-Screening Services')
# (338, u'C-Home Health')
# (339, u'C-Medicare Payments')
# (340, u'C-Home And Community')
# (341, u'C-Hospice')
# (342, u'C-Medical Transport')
# (343, u'C-Case Management')
# (344, u'C-Other Services')
# (345, u'C-Balance')
# (346, u'C-Collections')
# (347, u'C-Total Net')
# (348, None)
# (349, u'Arizona')
# (350, None)
# (351, u'Medical Assistance Program')
# (352, u'Service Category')
# (353, None)
# (354, u'Inpatient Hospital - Reg. Payments')
# (355, u'Inpatient Hospital - DSH')
# (356, u'Mental Health Facility Services - Reg. Payments')
# (357, u'Mental Health Facility - DSH')
# (358, u'Nursing Facility Services')
# (359, u'Intermediate Care Facility - Public')
# (360, u'Intermediate Care - Private')
# (361, u"Physicians' Services")
# (362, u'Outpatient Hospital Services')
# (363, u'Prescribed Drugs')
# (364, u'Drug Rebate Offset - National')
# (365, u'Drug Rebate Offset - State Sidebar Agreement')
# (366, u'Dental Services')
# (367, u'Other Practicioners')
# (368, u'Clinic Services')
# (369, u'Laboratory/Radiological')
# (370, u'Home Health Services')
# (371, u'Sterilizations')
# (372, u'Abortions')
# (373, u'EPSDT Screening')
# (374, u'Rural Health')
# (375, u'Medicare - Part A')
# (376, u'Medicare - Part B')
# (377, u'120% - 134% Of Poverty')
# (378, u'135% - 175% Of Poverty')
# (379, u'Coinsurance')
# (380, u'Medicaid - MCO')
# (381, u'Medicaid - PHP')
# (382, u'Medicaid - Group Health')
# (383, u'Medicaid - Coinsurance')
# (384, u'Medicaid - Other')
# (385, u'Home and Community')
# (386, u'Home And Community - Disabled Elderly')
# (387, u'Community Supported')
# (388, u'All-Inclusive Care Elderly')
# (389, u'Personal Care Services')
# (390, u'Targeted Case Management')
# (391, u'Primary Care Case Management')
# (392, u'Hospice Benefits')
# (393, u'Emergency')
# (394, u'Federally-Qualified Health Center')
# (395, u'Other Care Services')
# (396, u'Balance')
# (397, u'Collections')
# (398, u'Total Net Expenditures')
# (399, u'C-Premiums: Up To 150% - Gross Premiums Paid')
# (400, u'C-Premiums: Up To 150% - Cost Sharing Offset')
# (401, u'C-Premiums: Over 150% - Gross Premiums Paid')
# (402, u'C-Premiums: Over 150% - Cost Sharing Offset')
# (403, u'C-Inpatient Hospital Services - Reg. Payments')
# (404, u'C-Inpatient Hospital Services - DSH')
# (405, u'C-Inpatient Mental Health - Reg. Payment')
# (406, u'C-Inpatient Mental Health - DSH')
# (407, u'C-Nursing Care Services')
# (408, u'C-Physician/Surgical')
# (409, u'C-Outpatient Hospital Services')
# (410, u'C-Outpatient Mental Health')
# (411, u'C-Prescribed Drugs')
# (412, u'C-Drug Rebate - National')
# (413, u'C-Drug Rebate - State')
# (414, u'C-Dental Services')
# (415, u'C-Vision Sevices')
# (416, u'C-Other Practitioners')
# (417, u'C-Clinic Services')
# (418, u'C-Therapy Services')
# (419, u'C-Laboratory/Radiological Services')
# (420, u'C-Medical Equipment')
# (421, u'C-Family Planning')
# (422, u'C-Abortions')
# (423, u'C-Screening Services')
# (424, u'C-Home Health')
# (425, u'C-Medicare Payments')
# (426, u'C-Home And Community')
# (427, u'C-Hospice')
# (428, u'C-Medical Transport')
# (429, u'C-Case Management')
# (430, u'C-Other Services')
# (431, u'C-Balance')
# (432, u'C-Collections')
# (433, u'C-Total Net')
# (434, None)
# (435, u'California')
# (436, None)
# (437, u'Medical Assistance Program')
# (438, u'Service Category')
# (439, None)
# (440, u'Inpatient Hospital - Reg. Payments')
# (441, u'Inpatient Hospital - DSH')
# (442, u'Mental Health Facility Services - Reg. Payments')
# (443, u'Mental Health Facility - DSH')
# (444, u'Nursing Facility Services')
# (445, u'Intermediate Care Facility - Public')
# (446, u'Intermediate Care - Private')
# (447, u"Physicians' Services")
# (448, u'Outpatient Hospital Services')
# (449, u'Prescribed Drugs')
# (450, u'Drug Rebate Offset - National')
# (451, u'Drug Rebate Offset - State Sidebar Agreement')
# (452, u'Dental Services')
# (453, u'Other Practicioners')
# (454, u'Clinic Services')
# (455, u'Laboratory/Radiological')
# (456, u'Home Health Services')
# (457, u'Sterilizations')
# (458, u'Abortions')
# (459, u'EPSDT Screening')
# (460, u'Rural Health')
# (461, u'Medicare - Part A')
# (462, u'Medicare - Part B')
# (463, u'120% - 134% Of Poverty')
# (464, u'135% - 175% Of Poverty')
# (465, u'Coinsurance')
# (466, u'Medicaid - MCO')
# (467, u'Medicaid - PHP')
# (468, u'Medicaid - Group Health')
# (469, u'Medicaid - Coinsurance')
# (470, u'Medicaid - Other')
# (471, u'Home and Community')
# (472, u'Home And Community - Disabled Elderly')
# (473, u'Community Supported')
# (474, u'All-Inclusive Care Elderly')
# (475, u'Personal Care Services')
# (476, u'Targeted Case Management')
# (477, u'Primary Care Case Management')
# (478, u'Hospice Benefits')
# (479, u'Emergency')
# (480, u'Federally-Qualified Health Center')
# (481, u'Other Care Services')
# (482, u'Balance')
# (483, u'Collections')
# (484, u'Total Net Expenditures')
# (485, u'C-Premiums: Up To 150% - Gross Premiums Paid')
# (486, u'C-Premiums: Up To 150% - Cost Sharing Offset')
# (487, u'C-Premiums: Over 150% - Gross Premiums Paid')
# (488, u'C-Premiums: Over 150% - Cost Sharing Offset')
# (489, u'C-Inpatient Hospital Services - Reg. Payments')
# (490, u'C-Inpatient Hospital Services - DSH')
# (491, u'C-Inpatient Mental Health - Reg. Payment')
# (492, u'C-Inpatient Mental Health - DSH')
# (493, u'C-Nursing Care Services')
# (494, u'C-Physician/Surgical')
# (495, u'C-Outpatient Hospital Services')
# (496, u'C-Outpatient Mental Health')
# (497, u'C-Prescribed Drugs')
# (498, u'C-Drug Rebate - National')
# (499, u'C-Drug Rebate - State')
# (500, u'C-Dental Services')
# (501, u'C-Vision Sevices')
# (502, u'C-Other Practitioners')
# (503, u'C-Clinic Services')
# (504, u'C-Therapy Services')
# (505, u'C-Laboratory/Radiological Services')
# (506, u'C-Medical Equipment')
# (507, u'C-Family Planning')
# (508, u'C-Abortions')
# (509, u'C-Screening Services')
# (510, u'C-Home Health')
# (511, u'C-Medicare Payments')
# (512, u'C-Home And Community')
# (513, u'C-Hospice')
# (514, u'C-Medical Transport')
# (515, u'C-Case Management')
# (516, u'C-Other Services')
# (517, u'C-Balance')
# (518, u'C-Collections')
# (519, u'C-Total Net')
# (520, None)
# (521, u'N. Mariana Islands')
# (522, None)
# (523, u'Medical Assistance Program')
# (524, u'Service Category')
# (525, None)
# (526, u'Inpatient Hospital - Reg. Payments')
# (527, u'Inpatient Hospital - DSH')
# (528, u'Mental Health Facility Services - Reg. Payments')
# (529, u'Mental Health Facility - DSH')
# (530, u'Nursing Facility Services')
# (531, u'Intermediate Care Facility - Public')
# (532, u'Intermediate Care - Private')
# (533, u"Physicians' Services")
# (534, u'Outpatient Hospital Services')
# (535, u'Prescribed Drugs')
# (536, u'Drug Rebate Offset - National')
# (537, u'Drug Rebate Offset - State Sidebar Agreement')
# (538, u'Dental Services')
# (539, u'Other Practicioners')
# (540, u'Clinic Services')
# (541, u'Laboratory/Radiological')
# (542, u'Home Health Services')
# (543, u'Sterilizations')
# (544, u'Abortions')
# (545, u'EPSDT Screening')
# (546, u'Rural Health')
# (547, u'Medicare - Part A')
# (548, u'Medicare - Part B')
# (549, u'120% - 134% Of Poverty')
# (550, u'135% - 175% Of Poverty')
# (551, u'Coinsurance')
# (552, u'Medicaid - MCO')
# (553, u'Medicaid - PHP')
# (554, u'Medicaid - Group Health')
# (555, u'Medicaid - Coinsurance')
# (556, u'Medicaid - Other')
# (557, u'Home and Community')
# (558, u'Home And Community - Disabled Elderly')
# (559, u'Community Supported')
# (560, u'All-Inclusive Care Elderly')
# (561, u'Personal Care Services')
# (562, u'Targeted Case Management')
# (563, u'Primary Care Case Management')
# (564, u'Hospice Benefits')
# (565, u'Emergency')
# (566, u'Federally-Qualified Health Center')
# (567, u'Other Care Services')
# (568, u'Balance')
# (569, u'Collections')
# (570, u'Total Net Expenditures')
# (571, u'C-Premiums: Up To 150% - Gross Premiums Paid')
# (572, u'C-Premiums: Up To 150% - Cost Sharing Offset')
# (573, u'C-Premiums: Over 150% - Gross Premiums Paid')
# (574, u'C-Premiums: Over 150% - Cost Sharing Offset')
# (575, u'C-Inpatient Hospital Services - Reg. Payments')
# (576, u'C-Inpatient Hospital Services - DSH')
# (577, u'C-Inpatient Mental Health - Reg. Payment')
# (578, u'C-Inpatient Mental Health - DSH')
# (579, u'C-Nursing Care Services')
# (580, u'C-Physician/Surgical')
# (581, u'C-Outpatient Hospital Services')
# (582, u'C-Outpatient Mental Health')
# (583, u'C-Prescribed Drugs')
# (584, u'C-Drug Rebate - National')
# (585, u'C-Drug Rebate - State')
# (586, u'C-Dental Services')
# (587, u'C-Vision Sevices')
# (588, u'C-Other Practitioners')
# (589, u'C-Clinic Services')
# (590, u'C-Therapy Services')
# (591, u'C-Laboratory/Radiological Services')
# (592, u'C-Medical Equipment')
# (593, u'C-Family Planning')
# (594, u'C-Abortions')
# (595, u'C-Screening Services')
# (596, u'C-Home Health')
# (597, u'C-Medicare Payments')
# (598, u'C-Home And Community')
# (599, u'C-Hospice')
# (600, u'C-Medical Transport')
# (601, u'C-Case Management')
# (602, u'C-Other Services')
# (603, u'C-Balance')
# (604, u'C-Collections')
# (605, u'C-Total Net')
# (606, None)
# (607, u'Colorado')
# (608, None)
# (609, u'Medical Assistance Program')
# (610, u'Service Category')
# (611, None)
# (612, u'Inpatient Hospital - Reg. Payments')
# (613, u'Inpatient Hospital - DSH')
# (614, u'Mental Health Facility Services - Reg. Payments')
# (615, u'Mental Health Facility - DSH')
# (616, u'Nursing Facility Services')
# (617, u'Intermediate Care Facility - Public')
# (618, u'Intermediate Care - Private')
# (619, u"Physicians' Services")
# (620, u'Outpatient Hospital Services')
# (621, u'Prescribed Drugs')
# (622, u'Drug Rebate Offset - National')
# (623, u'Drug Rebate Offset - State Sidebar Agreement')
# (624, u'Dental Services')
# (625, u'Other Practicioners')
# (626, u'Clinic Services')
# (627, u'Laboratory/Radiological')
# (628, u'Home Health Services')
# (629, u'Sterilizations')
# (630, u'Abortions')
# (631, u'EPSDT Screening')
# (632, u'Rural Health')
# (633, u'Medicare - Part A')
# (634, u'Medicare - Part B')
# (635, u'120% - 134% Of Poverty')
# (636, u'135% - 175% Of Poverty')
# (637, u'Coinsurance')
# (638, u'Medicaid - MCO')
# (639, u'Medicaid - PHP')
# (640, u'Medicaid - Group Health')
# (641, u'Medicaid - Coinsurance')
# (642, u'Medicaid - Other')
# (643, u'Home and Community')
# (644, u'Home And Community - Disabled Elderly')
# (645, u'Community Supported')
# (646, u'All-Inclusive Care Elderly')
# (647, u'Personal Care Services')
# (648, u'Targeted Case Management')
# (649, u'Primary Care Case Management')
# (650, u'Hospice Benefits')
# (651, u'Emergency')
# (652, u'Federally-Qualified Health Center')
# (653, u'Other Care Services')
# (654, u'Balance')
# (655, u'Collections')
# (656, u'Total Net Expenditures')
# (657, u'C-Premiums: Up To 150% - Gross Premiums Paid')
# (658, u'C-Premiums: Up To 150% - Cost Sharing Offset')
# (659, u'C-Premiums: Over 150% - Gross Premiums Paid')
# (660, u'C-Premiums: Over 150% - Cost Sharing Offset')
# (661, u'C-Inpatient Hospital Services - Reg. Payments')
# (662, u'C-Inpatient Hospital Services - DSH')
# (663, u'C-Inpatient Mental Health - Reg. Payment')
# (664, u'C-Inpatient Mental Health - DSH')
# (665, u'C-Nursing Care Services')
# (666, u'C-Physician/Surgical')
# (667, u'C-Outpatient Hospital Services')
# (668, u'C-Outpatient Mental Health')
# (669, u'C-Prescribed Drugs')
# (670, u'C-Drug Rebate - National')
# (671, u'C-Drug Rebate - State')
# (672, u'C-Dental Services')
# (673, u'C-Vision Sevices')
# (674, u'C-Other Practitioners')
# (675, u'C-Clinic Services')
# (676, u'C-Therapy Services')
# (677, u'C-Laboratory/Radiological Services')
# (678, u'C-Medical Equipment')
# (679, u'C-Family Planning')
# (680, u'C-Abortions')
# (681, u'C-Screening Services')
# (682, u'C-Home Health')
# (683, u'C-Medicare Payments')
# (684, u'C-Home And Community')
# (685, u'C-Hospice')
# (686, u'C-Medical Transport')
# (687, u'C-Case Management')
# (688, u'C-Other Services')
# (689, u'C-Balance')
# (690, u'C-Collections')
# (691, u'C-Total Net')
# (692, None)
# (693, u'Connecticut')
# (694, None)
# (695, u'Medical Assistance Program')
# (696, u'Service Category')
# (697, None)
# (698, u'Inpatient Hospital - Reg. Payments')
# (699, u'Inpatient Hospital - DSH')
# (700, u'Mental Health Facility Services - Reg. Payments')
# (701, u'Mental Health Facility - DSH')
# (702, u'Nursing Facility Services')
# (703, u'Intermediate Care Facility - Public')
# (704, u'Intermediate Care - Private')
# (705, u"Physicians' Services")
# (706, u'Outpatient Hospital Services')
# (707, u'Prescribed Drugs')
# (708, u'Drug Rebate Offset - National')
# (709, u'Drug Rebate Offset - State Sidebar Agreement')
# (710, u'Dental Services')
# (711, u'Other Practicioners')
# (712, u'Clinic Services')
# (713, u'Laboratory/Radiological')
# (714, u'Home Health Services')
# (715, u'Sterilizations')
# (716, u'Abortions')
# (717, u'EPSDT Screening')
# (718, u'Rural Health')
# (719, u'Medicare - Part A')
# (720, u'Medicare - Part B')
# (721, u'120% - 134% Of Poverty')
# (722, u'135% - 175% Of Poverty')
# (723, u'Coinsurance')
# (724, u'Medicaid - MCO')
# (725, u'Medicaid - PHP')
# (726, u'Medicaid - Group Health')
# (727, u'Medicaid - Coinsurance')
# (728, u'Medicaid - Other')
# (729, u'Home and Community')
# (730, u'Home And Community - Disabled Elderly')
# (731, u'Community Supported')
# (732, u'All-Inclusive Care Elderly')
# (733, u'Personal Care Services')
# (734, u'Targeted Case Management')
# (735, u'Primary Care Case Management')
# (736, u'Hospice Benefits')
# (737, u'Emergency')
# (738, u'Federally-Qualified Health Center')
# (739, u'Other Care Services')
# (740, u'Balance')
# (741, u'Collections')
# (742, u'Total Net Expenditures')
# (743, u'C-Premiums: Up To 150% - Gross Premiums Paid')
# (744, u'C-Premiums: Up To 150% - Cost Sharing Offset')
# (745, u'C-Premiums: Over 150% - Gross Premiums Paid')
# (746, u'C-Premiums: Over 150% - Cost Sharing Offset')
# (747, u'C-Inpatient Hospital Services - Reg. Payments')
# (748, u'C-Inpatient Hospital Services - DSH')
# (749, u'C-Inpatient Mental Health - Reg. Payment')
# (750, u'C-Inpatient Mental Health - DSH')
# (751, u'C-Nursing Care Services')
# (752, u'C-Physician/Surgical')
# (753, u'C-Outpatient Hospital Services')
# (754, u'C-Outpatient Mental Health')
# (755, u'C-Prescribed Drugs')
# (756, u'C-Drug Rebate - National')
# (757, u'C-Drug Rebate - State')
# (758, u'C-Dental Services')
# (759, u'C-Vision Sevices')
# (760, u'C-Other Practitioners')
# (761, u'C-Clinic Services')
# (762, u'C-Therapy Services')
# (763, u'C-Laboratory/Radiological Services')
# (764, u'C-Medical Equipment')
# (765, u'C-Family Planning')
# (766, u'C-Abortions')
# (767, u'C-Screening Services')
# (768, u'C-Home Health')
# (769, u'C-Medicare Payments')
# (770, u'C-Home And Community')
# (771, u'C-Hospice')
# (772, u'C-Medical Transport')
# (773, u'C-Case Management')
# (774, u'C-Other Services')
# (775, u'C-Balance')
# (776, u'C-Collections')
# (777, u'C-Total Net')
# (778, None)
# (779, u'Dist. Of Col.')
# (780, None)
# (781, u'Medical Assistance Program')
# (782, u'Service Category')
# (783, None)
# (784, u'Inpatient Hospital - Reg. Payments')
# (785, u'Inpatient Hospital - DSH')
# (786, u'Mental Health Facility Services - Reg. Payments')
# (787, u'Mental Health Facility - DSH')
# (788, u'Nursing Facility Services')
# (789, u'Intermediate Care Facility - Public')
# (790, u'Intermediate Care - Private')
# (791, u"Physicians' Services")
# (792, u'Outpatient Hospital Services')
# (793, u'Prescribed Drugs')
# (794, u'Drug Rebate Offset - National')
# (795, u'Drug Rebate Offset - State Sidebar Agreement')
# (796, u'Dental Services')
# (797, u'Other Practicioners')
# (798, u'Clinic Services')
# (799, u'Laboratory/Radiological')
# (800, u'Home Health Services')
# (801, u'Sterilizations')
# (802, u'Abortions')
# (803, u'EPSDT Screening')
# (804, u'Rural Health')
# (805, u'Medicare - Part A')
# (806, u'Medicare - Part B')
# (807, u'120% - 134% Of Poverty')
# (808, u'135% - 175% Of Poverty')
# (809, u'Coinsurance')
# (810, u'Medicaid - MCO')
# (811, u'Medicaid - PHP')
# (812, u'Medicaid - Group Health')
# (813, u'Medicaid - Coinsurance')
# (814, u'Medicaid - Other')
# (815, u'Home and Community')
# (816, u'Home And Community - Disabled Elderly')
# (817, u'Community Supported')
# (818, u'All-Inclusive Care Elderly')
# (819, u'Personal Care Services')
# (820, u'Targeted Case Management')
# (821, u'Primary Care Case Management')
# (822, u'Hospice Benefits')
# (823, u'Emergency')
# (824, u'Federally-Qualified Health Center')
# (825, u'Other Care Services')
# (826, u'Balance')
# (827, u'Collections')
# (828, u'Total Net Expenditures')
# (829, u'C-Premiums: Up To 150% - Gross Premiums Paid')
# (830, u'C-Premiums: Up To 150% - Cost Sharing Offset')
# (831, u'C-Premiums: Over 150% - Gross Premiums Paid')
# (832, u'C-Premiums: Over 150% - Cost Sharing Offset')
# (833, u'C-Inpatient Hospital Services - Reg. Payments')
# (834, u'C-Inpatient Hospital Services - DSH')
# (835, u'C-Inpatient Mental Health - Reg. Payment')
# (836, u'C-Inpatient Mental Health - DSH')
# (837, u'C-Nursing Care Services')
# (838, u'C-Physician/Surgical')
# (839, u'C-Outpatient Hospital Services')
# (840, u'C-Outpatient Mental Health')
# (841, u'C-Prescribed Drugs')
# (842, u'C-Drug Rebate - National')
# (843, u'C-Drug Rebate - State')
# (844, u'C-Dental Services')
# (845, u'C-Vision Sevices')
# (846, u'C-Other Practitioners')
# (847, u'C-Clinic Services')
# (848, u'C-Therapy Services')
# (849, u'C-Laboratory/Radiological Services')
# (850, u'C-Medical Equipment')
# (851, u'C-Family Planning')
# (852, u'C-Abortions')
# (853, u'C-Screening Services')
# (854, u'C-Home Health')
# (855, u'C-Medicare Payments')
# (856, u'C-Home And Community')
# (857, u'C-Hospice')
# (858, u'C-Medical Transport')
# (859, u'C-Case Management')
# (860, u'C-Other Services')
# (861, u'C-Balance')
# (862, u'C-Collections')
# (863, u'C-Total Net')
# (864, None)
# (865, u'Delaware')
# (866, None)
# (867, u'Medical Assistance Program')
# (868, u'Service Category')
# (869, None)
# (870, u'Inpatient Hospital - Reg. Payments')
# (871, u'Inpatient Hospital - DSH')
# (872, u'Mental Health Facility Services - Reg. Payments')
# (873, u'Mental Health Facility - DSH')
# (874, u'Nursing Facility Services')
# (875, u'Intermediate Care Facility - Public')
# (876, u'Intermediate Care - Private')
# (877, u"Physicians' Services")
# (878, u'Outpatient Hospital Services')
# (879, u'Prescribed Drugs')
# (880, u'Drug Rebate Offset - National')
# (881, u'Drug Rebate Offset - State Sidebar Agreement')
# (882, u'Dental Services')
# (883, u'Other Practicioners')
# (884, u'Clinic Services')
# (885, u'Laboratory/Radiological')
# (886, u'Home Health Services')
# (887, u'Sterilizations')
# (888, u'Abortions')
# (889, u'EPSDT Screening')
# (890, u'Rural Health')
# (891, u'Medicare - Part A')
# (892, u'Medicare - Part B')
# (893, u'120% - 134% Of Poverty')
# (894, u'135% - 175% Of Poverty')
# (895, u'Coinsurance')
# (896, u'Medicaid - MCO')
# (897, u'Medicaid - PHP')
# (898, u'Medicaid - Group Health')
# (899, u'Medicaid - Coinsurance')
# (900, u'Medicaid - Other')
# (901, u'Home and Community')
# (902, u'Home And Community - Disabled Elderly')
# (903, u'Community Supported')
# (904, u'All-Inclusive Care Elderly')
# (905, u'Personal Care Services')
# (906, u'Targeted Case Management')
# (907, u'Primary Care Case Management')
# (908, u'Hospice Benefits')
# (909, u'Emergency')
# (910, u'Federally-Qualified Health Center')
# (911, u'Other Care Services')
# (912, u'Balance')
# (913, u'Collections')
# (914, u'Total Net Expenditures')
# (915, u'C-Premiums: Up To 150% - Gross Premiums Paid')
# (916, u'C-Premiums: Up To 150% - Cost Sharing Offset')
# (917, u'C-Premiums: Over 150% - Gross Premiums Paid')
# (918, u'C-Premiums: Over 150% - Cost Sharing Offset')
# (919, u'C-Inpatient Hospital Services - Reg. Payments')
# (920, u'C-Inpatient Hospital Services - DSH')
# (921, u'C-Inpatient Mental Health - Reg. Payment')
# (922, u'C-Inpatient Mental Health - DSH')
# (923, u'C-Nursing Care Services')
# (924, u'C-Physician/Surgical')
# (925, u'C-Outpatient Hospital Services')
# (926, u'C-Outpatient Mental Health')
# (927, u'C-Prescribed Drugs')
# (928, u'C-Drug Rebate - National')
# (929, u'C-Drug Rebate - State')
# (930, u'C-Dental Services')
# (931, u'C-Vision Sevices')
# (932, u'C-Other Practitioners')
# (933, u'C-Clinic Services')
# (934, u'C-Therapy Services')
# (935, u'C-Laboratory/Radiological Services')
# (936, u'C-Medical Equipment')
# (937, u'C-Family Planning')
# (938, u'C-Abortions')
# (939, u'C-Screening Services')
# (940, u'C-Home Health')
# (941, u'C-Medicare Payments')
# (942, u'C-Home And Community')
# (943, u'C-Hospice')
# (944, u'C-Medical Transport')
# (945, u'C-Case Management')
# (946, u'C-Other Services')
# (947, u'C-Balance')
# (948, u'C-Collections')
# (949, u'C-Total Net')
# (950, None)
# (951, u'Florida')
# (952, None)
# (953, u'Medical Assistance Program')
# (954, u'Service Category')
# (955, None)
# (956, u'Inpatient Hospital - Reg. Payments')
# (957, u'Inpatient Hospital - DSH')
# (958, u'Mental Health Facility Services - Reg. Payments')
# (959, u'Mental Health Facility - DSH')
# (960, u'Nursing Facility Services')
# (961, u'Intermediate Care Facility - Public')
# (962, u'Intermediate Care - Private')
# (963, u"Physicians' Services")
# (964, u'Outpatient Hospital Services')
# (965, u'Prescribed Drugs')
# (966, u'Drug Rebate Offset - National')
# (967, u'Drug Rebate Offset - State Sidebar Agreement')
# (968, u'Dental Services')
# (969, u'Other Practicioners')
# (970, u'Clinic Services')
# (971, u'Laboratory/Radiological')
# (972, u'Home Health Services')
# (973, u'Sterilizations')
# (974, u'Abortions')
# (975, u'EPSDT Screening')
# (976, u'Rural Health')
# (977, u'Medicare - Part A')
# (978, u'Medicare - Part B')
# (979, u'120% - 134% Of Poverty')
# (980, u'135% - 175% Of Poverty')
# (981, u'Coinsurance')
# (982, u'Medicaid - MCO')
# (983, u'Medicaid - PHP')
# (984, u'Medicaid - Group Health')
# (985, u'Medicaid - Coinsurance')
# (986, u'Medicaid - Other')
# (987, u'Home and Community')
# (988, u'Home And Community - Disabled Elderly')
# (989, u'Community Supported')
# (990, u'All-Inclusive Care Elderly')
# (991, u'Personal Care Services')
# (992, u'Targeted Case Management')
# (993, u'Primary Care Case Management')
# (994, u'Hospice Benefits')
# (995, u'Emergency')
# (996, u'Federally-Qualified Health Center')
# (997, u'Other Care Services')
# (998, u'Balance')
# (999, u'Collections')
# (1000, u'Total Net Expenditures')
# (1001, u'C-Premiums: Up To 150% - Gross Premiums Paid')
# (1002, u'C-Premiums: Up To 150% - Cost Sharing Offset')
# (1003, u'C-Premiums: Over 150% - Gross Premiums Paid')
# (1004, u'C-Premiums: Over 150% - Cost Sharing Offset')
# (1005, u'C-Inpatient Hospital Services - Reg. Payments')
# (1006, u'C-Inpatient Hospital Services - DSH')
# (1007, u'C-Inpatient Mental Health - Reg. Payment')
# (1008, u'C-Inpatient Mental Health - DSH')
# (1009, u'C-Nursing Care Services')
# (1010, u'C-Physician/Surgical')
# (1011, u'C-Outpatient Hospital Services')
# (1012, u'C-Outpatient Mental Health')
# (1013, u'C-Prescribed Drugs')
# (1014, u'C-Drug Rebate - National')
# (1015, u'C-Drug Rebate - State')
# (1016, u'C-Dental Services')
# (1017, u'C-Vision Sevices')
# (1018, u'C-Other Practitioners')
# (1019, u'C-Clinic Services')
# (1020, u'C-Therapy Services')
# (1021, u'C-Laboratory/Radiological Services')
# (1022, u'C-Medical Equipment')
# (1023, u'C-Family Planning')
# (1024, u'C-Abortions')
# (1025, u'C-Screening Services')
# (1026, u'C-Home Health')
# (1027, u'C-Medicare Payments')
# (1028, u'C-Home And Community')
# (1029, u'C-Hospice')
# (1030, u'C-Medical Transport')
# (1031, u'C-Case Management')
# (1032, u'C-Other Services')
# (1033, u'C-Balance')
# (1034, u'C-Collections')
# (1035, u'C-Total Net')
# (1036, None)
# (1037, u'Georgia')
# (1038, None)
# (1039, u'Medical Assistance Program')
# (1040, u'Service Category')
# (1041, None)
# (1042, u'Inpatient Hospital - Reg. Payments')
# (1043, u'Inpatient Hospital - DSH')
# (1044, u'Mental Health Facility Services - Reg. Payments')
# (1045, u'Mental Health Facility - DSH')
# (1046, u'Nursing Facility Services')
# (1047, u'Intermediate Care Facility - Public')
# (1048, u'Intermediate Care - Private')
# (1049, u"Physicians' Services")
# (1050, u'Outpatient Hospital Services')
# (1051, u'Prescribed Drugs')
# (1052, u'Drug Rebate Offset - National')
# (1053, u'Drug Rebate Offset - State Sidebar Agreement')
# (1054, u'Dental Services')
# (1055, u'Other Practicioners')
# (1056, u'Clinic Services')
# (1057, u'Laboratory/Radiological')
# (1058, u'Home Health Services')
# (1059, u'Sterilizations')
# (1060, u'Abortions')
# (1061, u'EPSDT Screening')
# (1062, u'Rural Health')
# (1063, u'Medicare - Part A')
# (1064, u'Medicare - Part B')
# (1065, u'120% - 134% Of Poverty')
# (1066, u'135% - 175% Of Poverty')
# (1067, u'Coinsurance')
# (1068, u'Medicaid - MCO')
# (1069, u'Medicaid - PHP')
# (1070, u'Medicaid - Group Health')
# (1071, u'Medicaid - Coinsurance')
# (1072, u'Medicaid - Other')
# (1073, u'Home and Community')
# (1074, u'Home And Community - Disabled Elderly')
# (1075, u'Community Supported')
# (1076, u'All-Inclusive Care Elderly')
# (1077, u'Personal Care Services')
# (1078, u'Targeted Case Management')
# (1079, u'Primary Care Case Management')
# (1080, u'Hospice Benefits')
# (1081, u'Emergency')
# (1082, u'Federally-Qualified Health Center')
# (1083, u'Other Care Services')
# (1084, u'Balance')
# (1085, u'Collections')
# (1086, u'Total Net Expenditures')
# (1087, u'C-Premiums: Up To 150% - Gross Premiums Paid')
# (1088, u'C-Premiums: Up To 150% - Cost Sharing Offset')
# (1089, u'C-Premiums: Over 150% - Gross Premiums Paid')
# (1090, u'C-Premiums: Over 150% - Cost Sharing Offset')
# (1091, u'C-Inpatient Hospital Services - Reg. Payments')
# (1092, u'C-Inpatient Hospital Services - DSH')
# (1093, u'C-Inpatient Mental Health - Reg. Payment')
# (1094, u'C-Inpatient Mental Health - DSH')
# (1095, u'C-Nursing Care Services')
# (1096, u'C-Physician/Surgical')
# (1097, u'C-Outpatient Hospital Services')
# (1098, u'C-Outpatient Mental Health')
# (1099, u'C-Prescribed Drugs')
# (1100, u'C-Drug Rebate - National')
# (1101, u'C-Drug Rebate - State')
# (1102, u'C-Dental Services')
# (1103, u'C-Vision Sevices')
# (1104, u'C-Other Practitioners')
# (1105, u'C-Clinic Services')
# (1106, u'C-Therapy Services')
# (1107, u'C-Laboratory/Radiological Services')
# (1108, u'C-Medical Equipment')
# (1109, u'C-Family Planning')
# (1110, u'C-Abortions')
# (1111, u'C-Screening Services')
# (1112, u'C-Home Health')
# (1113, u'C-Medicare Payments')
# (1114, u'C-Home And Community')
# (1115, u'C-Hospice')
# (1116, u'C-Medical Transport')
# (1117, u'C-Case Management')
# (1118, u'C-Other Services')
# (1119, u'C-Balance')
# (1120, u'C-Collections')
# (1121, u'C-Total Net')
# (1122, None)
# (1123, u'Guam')
# (1124, None)
# (1125, u'Medical Assistance Program')
# (1126, u'Service Category')
# (1127, None)
# (1128, u'Inpatient Hospital - Reg. Payments')
# (1129, u'Inpatient Hospital - DSH')
# (1130, u'Mental Health Facility Services - Reg. Payments')
# (1131, u'Mental Health Facility - DSH')
# (1132, u'Nursing Facility Services')
# (1133, u'Intermediate Care Facility - Public')
# (1134, u'Intermediate Care - Private')
# (1135, u"Physicians' Services")
# (1136, u'Outpatient Hospital Services')
# (1137, u'Prescribed Drugs')
# (1138, u'Drug Rebate Offset - National')
# (1139, u'Drug Rebate Offset - State Sidebar Agreement')
# (1140, u'Dental Services')
# (1141, u'Other Practicioners')
# (1142, u'Clinic Services')
# (1143, u'Laboratory/Radiological')
# (1144, u'Home Health Services')
# (1145, u'Sterilizations')
# (1146, u'Abortions')
# (1147, u'EPSDT Screening')
# (1148, u'Rural Health')
# (1149, u'Medicare - Part A')
# (1150, u'Medicare - Part B')
# (1151, u'120% - 134% Of Poverty')
# (1152, u'135% - 175% Of Poverty')
# (1153, u'Coinsurance')
# (1154, u'Medicaid - MCO')
# (1155, u'Medicaid - PHP')
# (1156, u'Medicaid - Group Health')
# (1157, u'Medicaid - Coinsurance')
# (1158, u'Medicaid - Other')
# (1159, u'Home and Community')
# (1160, u'Home And Community - Disabled Elderly')
# (1161, u'Community Supported')
# (1162, u'All-Inclusive Care Elderly')
# (1163, u'Personal Care Services')
# (1164, u'Targeted Case Management')
# (1165, u'Primary Care Case Management')
# (1166, u'Hospice Benefits')
# (1167, u'Emergency')
# (1168, u'Federally-Qualified Health Center')
# (1169, u'Other Care Services')
# (1170, u'Balance')
# (1171, u'Collections')
# (1172, u'Total Net Expenditures')
# (1173, u'C-Premiums: Up To 150% - Gross Premiums Paid')
# (1174, u'C-Premiums: Up To 150% - Cost Sharing Offset')
# (1175, u'C-Premiums: Over 150% - Gross Premiums Paid')
# (1176, u'C-Premiums: Over 150% - Cost Sharing Offset')
# (1177, u'C-Inpatient Hospital Services - Reg. Payments')
# (1178, u'C-Inpatient Hospital Services - DSH')
# (1179, u'C-Inpatient Mental Health - Reg. Payment')
# (1180, u'C-Inpatient Mental Health - DSH')
# (1181, u'C-Nursing Care Services')
# (1182, u'C-Physician/Surgical')
# (1183, u'C-Outpatient Hospital Services')
# (1184, u'C-Outpatient Mental Health')
# (1185, u'C-Prescribed Drugs')
# (1186, u'C-Drug Rebate - National')
# (1187, u'C-Drug Rebate - State')
# (1188, u'C-Dental Services')
# (1189, u'C-Vision Sevices')
# (1190, u'C-Other Practitioners')
# (1191, u'C-Clinic Services')
# (1192, u'C-Therapy Services')
# (1193, u'C-Laboratory/Radiological Services')
# (1194, u'C-Medical Equipment')
# (1195, u'C-Family Planning')
# (1196, u'C-Abortions')
# (1197, u'C-Screening Services')
# (1198, u'C-Home Health')
# (1199, u'C-Medicare Payments')
# (1200, u'C-Home And Community')
# (1201, u'C-Hospice')
# (1202, u'C-Medical Transport')
# (1203, u'C-Case Management')
# (1204, u'C-Other Services')
# (1205, u'C-Balance')
# (1206, u'C-Collections')
# (1207, u'C-Total Net')
# (1208, None)
# (1209, u'Hawaii')
# (1210, None)
# (1211, u'Medical Assistance Program')
# (1212, u'Service Category')
# (1213, None)
# (1214, u'Inpatient Hospital - Reg. Payments')
# (1215, u'Inpatient Hospital - DSH')
# (1216, u'Mental Health Facility Services - Reg. Payments')
# (1217, u'Mental Health Facility - DSH')
# (1218, u'Nursing Facility Services')
# (1219, u'Intermediate Care Facility - Public')
# (1220, u'Intermediate Care - Private')
# (1221, u"Physicians' Services")
# (1222, u'Outpatient Hospital Services')
# (1223, u'Prescribed Drugs')
# (1224, u'Drug Rebate Offset - National')
# (1225, u'Drug Rebate Offset - State Sidebar Agreement')
# (1226, u'Dental Services')
# (1227, u'Other Practicioners')
# (1228, u'Clinic Services')
# (1229, u'Laboratory/Radiological')
# (1230, u'Home Health Services')
# (1231, u'Sterilizations')
# (1232, u'Abortions')
# (1233, u'EPSDT Screening')
# (1234, u'Rural Health')
# (1235, u'Medicare - Part A')
# (1236, u'Medicare - Part B')
# (1237, u'120% - 134% Of Poverty')
# (1238, u'135% - 175% Of Poverty')
# (1239, u'Coinsurance')
# (1240, u'Medicaid - MCO')
# (1241, u'Medicaid - PHP')
# (1242, u'Medicaid - Group Health')
# (1243, u'Medicaid - Coinsurance')
# (1244, u'Medicaid - Other')
# (1245, u'Home and Community')
# (1246, u'Home And Community - Disabled Elderly')
# (1247, u'Community Supported')
# (1248, u'All-Inclusive Care Elderly')
# (1249, u'Personal Care Services')
# (1250, u'Targeted Case Management')
# (1251, u'Primary Care Case Management')
# (1252, u'Hospice Benefits')
# (1253, u'Emergency')
# (1254, u'Federally-Qualified Health Center')
# (1255, u'Other Care Services')
# (1256, u'Balance')
# (1257, u'Collections')
# (1258, u'Total Net Expenditures')
# (1259, u'C-Premiums: Up To 150% - Gross Premiums Paid')
# (1260, u'C-Premiums: Up To 150% - Cost Sharing Offset')
# (1261, u'C-Premiums: Over 150% - Gross Premiums Paid')
# (1262, u'C-Premiums: Over 150% - Cost Sharing Offset')
# (1263, u'C-Inpatient Hospital Services - Reg. Payments')
# (1264, u'C-Inpatient Hospital Services - DSH')
# (1265, u'C-Inpatient Mental Health - Reg. Payment')
# (1266, u'C-Inpatient Mental Health - DSH')
# (1267, u'C-Nursing Care Services')
# (1268, u'C-Physician/Surgical')
# (1269, u'C-Outpatient Hospital Services')
# (1270, u'C-Outpatient Mental Health')
# (1271, u'C-Prescribed Drugs')
# (1272, u'C-Drug Rebate - National')
# (1273, u'C-Drug Rebate - State')
# (1274, u'C-Dental Services')
# (1275, u'C-Vision Sevices')
# (1276, u'C-Other Practitioners')
# (1277, u'C-Clinic Services')
# (1278, u'C-Therapy Services')
# (1279, u'C-Laboratory/Radiological Services')
# (1280, u'C-Medical Equipment')
# (1281, u'C-Family Planning')
# (1282, u'C-Abortions')
# (1283, u'C-Screening Services')
# (1284, u'C-Home Health')
# (1285, u'C-Medicare Payments')
# (1286, u'C-Home And Community')
# (1287, u'C-Hospice')
# (1288, u'C-Medical Transport')
# (1289, u'C-Case Management')
# (1290, u'C-Other Services')
# (1291, u'C-Balance')
# (1292, u'C-Collections')
# (1293, u'C-Total Net')
# (1294, None)
# (1295, u'Iowa')
# (1296, None)
# (1297, u'Medical Assistance Program')
# (1298, u'Service Category')
# (1299, None)
# (1300, u'Inpatient Hospital - Reg. Payments')
# (1301, u'Inpatient Hospital - DSH')
# (1302, u'Mental Health Facility Services - Reg. Payments')
# (1303, u'Mental Health Facility - DSH')
# (1304, u'Nursing Facility Services')
# (1305, u'Intermediate Care Facility - Public')
# (1306, u'Intermediate Care - Private')
# (1307, u"Physicians' Services")
# (1308, u'Outpatient Hospital Services')
# (1309, u'Prescribed Drugs')
# (1310, u'Drug Rebate Offset - National')
# (1311, u'Drug Rebate Offset - State Sidebar Agreement')
# (1312, u'Dental Services')
# (1313, u'Other Practicioners')
# (1314, u'Clinic Services')
# (1315, u'Laboratory/Radiological')
# (1316, u'Home Health Services')
# (1317, u'Sterilizations')
# (1318, u'Abortions')
# (1319, u'EPSDT Screening')
# (1320, u'Rural Health')
# (1321, u'Medicare - Part A')
# (1322, u'Medicare - Part B')
# (1323, u'120% - 134% Of Poverty')
# (1324, u'135% - 175% Of Poverty')
# (1325, u'Coinsurance')
# (1326, u'Medicaid - MCO')
# (1327, u'Medicaid - PHP')
# (1328, u'Medicaid - Group Health')
# (1329, u'Medicaid - Coinsurance')
# (1330, u'Medicaid - Other')
# (1331, u'Home and Community')
# (1332, u'Home And Community - Disabled Elderly')
# (1333, u'Community Supported')
# (1334, u'All-Inclusive Care Elderly')
# (1335, u'Personal Care Services')
# (1336, u'Targeted Case Management')
# (1337, u'Primary Care Case Management')
# (1338, u'Hospice Benefits')
# (1339, u'Emergency')
# (1340, u'Federally-Qualified Health Center')
# (1341, u'Other Care Services')
# (1342, u'Balance')
# (1343, u'Collections')
# (1344, u'Total Net Expenditures')
# (1345, u'C-Premiums: Up To 150% - Gross Premiums Paid')
# (1346, u'C-Premiums: Up To 150% - Cost Sharing Offset')
# (1347, u'C-Premiums: Over 150% - Gross Premiums Paid')
# (1348, u'C-Premiums: Over 150% - Cost Sharing Offset')
# (1349, u'C-Inpatient Hospital Services - Reg. Payments')
# (1350, u'C-Inpatient Hospital Services - DSH')
# (1351, u'C-Inpatient Mental Health - Reg. Payment')
# (1352, u'C-Inpatient Mental Health - DSH')
# (1353, u'C-Nursing Care Services')
# (1354, u'C-Physician/Surgical')
# (1355, u'C-Outpatient Hospital Services')
# (1356, u'C-Outpatient Mental Health')
# (1357, u'C-Prescribed Drugs')
# (1358, u'C-Drug Rebate - National')
# (1359, u'C-Drug Rebate - State')
# (1360, u'C-Dental Services')
# (1361, u'C-Vision Sevices')
# (1362, u'C-Other Practitioners')
# (1363, u'C-Clinic Services')
# (1364, u'C-Therapy Services')
# (1365, u'C-Laboratory/Radiological Services')
# (1366, u'C-Medical Equipment')
# (1367, u'C-Family Planning')
# (1368, u'C-Abortions')
# (1369, u'C-Screening Services')
# (1370, u'C-Home Health')
# (1371, u'C-Medicare Payments')
# (1372, u'C-Home And Community')
# (1373, u'C-Hospice')
# (1374, u'C-Medical Transport')
# (1375, u'C-Case Management')
# (1376, u'C-Other Services')
# (1377, u'C-Balance')
# (1378, u'C-Collections')
# (1379, u'C-Total Net')
# (1380, None)
# (1381, u'Idaho')
# (1382, None)
# (1383, u'Medical Assistance Program')
# (1384, u'Service Category')
# (1385, None)
# (1386, u'Inpatient Hospital - Reg. Payments')
# (1387, u'Inpatient Hospital - DSH')
# (1388, u'Mental Health Facility Services - Reg. Payments')
# (1389, u'Mental Health Facility - DSH')
# (1390, u'Nursing Facility Services')
# (1391, u'Intermediate Care Facility - Public')
# (1392, u'Intermediate Care - Private')
# (1393, u"Physicians' Services")
# (1394, u'Outpatient Hospital Services')
# (1395, u'Prescribed Drugs')
# (1396, u'Drug Rebate Offset - National')
# (1397, u'Drug Rebate Offset - State Sidebar Agreement')
# (1398, u'Dental Services')
# (1399, u'Other Practicioners')
# (1400, u'Clinic Services')
# (1401, u'Laboratory/Radiological')
# (1402, u'Home Health Services')
# (1403, u'Sterilizations')
# (1404, u'Abortions')
# (1405, u'EPSDT Screening')
# (1406, u'Rural Health')
# (1407, u'Medicare - Part A')
# (1408, u'Medicare - Part B')
# (1409, u'120% - 134% Of Poverty')
# (1410, u'135% - 175% Of Poverty')
# (1411, u'Coinsurance')
# (1412, u'Medicaid - MCO')
# (1413, u'Medicaid - PHP')
# (1414, u'Medicaid - Group Health')
# (1415, u'Medicaid - Coinsurance')
# (1416, u'Medicaid - Other')
# (1417, u'Home and Community')
# (1418, u'Home And Community - Disabled Elderly')
# (1419, u'Community Supported')
# (1420, u'All-Inclusive Care Elderly')
# (1421, u'Personal Care Services')
# (1422, u'Targeted Case Management')
# (1423, u'Primary Care Case Management')
# (1424, u'Hospice Benefits')
# (1425, u'Emergency')
# (1426, u'Federally-Qualified Health Center')
# (1427, u'Other Care Services')
# (1428, u'Balance')
# (1429, u'Collections')
# (1430, u'Total Net Expenditures')
# (1431, u'C-Premiums: Up To 150% - Gross Premiums Paid')
# (1432, u'C-Premiums: Up To 150% - Cost Sharing Offset')
# (1433, u'C-Premiums: Over 150% - Gross Premiums Paid')
# (1434, u'C-Premiums: Over 150% - Cost Sharing Offset')
# (1435, u'C-Inpatient Hospital Services - Reg. Payments')
# (1436, u'C-Inpatient Hospital Services - DSH')
# (1437, u'C-Inpatient Mental Health - Reg. Payment')
# (1438, u'C-Inpatient Mental Health - DSH')
# (1439, u'C-Nursing Care Services')
# (1440, u'C-Physician/Surgical')
# (1441, u'C-Outpatient Hospital Services')
# (1442, u'C-Outpatient Mental Health')
# (1443, u'C-Prescribed Drugs')
# (1444, u'C-Drug Rebate - National')
# (1445, u'C-Drug Rebate - State')
# (1446, u'C-Dental Services')
# (1447, u'C-Vision Sevices')
# (1448, u'C-Other Practitioners')
# (1449, u'C-Clinic Services')
# (1450, u'C-Therapy Services')
# (1451, u'C-Laboratory/Radiological Services')
# (1452, u'C-Medical Equipment')
# (1453, u'C-Family Planning')
# (1454, u'C-Abortions')
# (1455, u'C-Screening Services')
# (1456, u'C-Home Health')
# (1457, u'C-Medicare Payments')
# (1458, u'C-Home And Community')
# (1459, u'C-Hospice')
# (1460, u'C-Medical Transport')
# (1461, u'C-Case Management')
# (1462, u'C-Other Services')
# (1463, u'C-Balance')
# (1464, u'C-Collections')
# (1465, u'C-Total Net')
# (1466, None)
# (1467, u'Illinois')
# ...
# (4516, u'All-Inclusive Care Elderly')
# (4517, u'Personal Care Services')
# (4518, u'Targeted Case Management')
# (4519, u'Primary Care Case Management')
# (4520, u'Hospice Benefits')
# (4521, u'Emergency')
# (4522, u'Federally-Qualified Health Center')
# (4523, u'Other Care Services')
# (4524, u'Balance')
# (4525, u'Collections')
# (4526, u'Total Net Expenditures')
# (4527, u'C-Premiums: Up To 150% - Gross Premiums Paid')
# (4528, u'C-Premiums: Up To 150% - Cost Sharing Offset')
# (4529, u'C-Premiums: Over 150% - Gross Premiums Paid')
# (4530, u'C-Premiums: Over 150% - Cost Sharing Offset')
# (4531, u'C-Inpatient Hospital Services - Reg. Payments')
# (4532, u'C-Inpatient Hospital Services - DSH')
# (4533, u'C-Inpatient Mental Health - Reg. Payment')
# (4534, u'C-Inpatient Mental Health - DSH')
# (4535, u'C-Nursing Care Services')
# (4536, u'C-Physician/Surgical')
# (4537, u'C-Outpatient Hospital Services')
# (4538, u'C-Outpatient Mental Health')
# (4539, u'C-Prescribed Drugs')
# (4540, u'C-Drug Rebate - National')
# (4541, u'C-Drug Rebate - State')
# (4542, u'C-Dental Services')
# (4543, u'C-Vision Sevices')
# (4544, u'C-Other Practitioners')
# (4545, u'C-Clinic Services')
# (4546, u'C-Therapy Services')
# (4547, u'C-Laboratory/Radiological Services')
# (4548, u'C-Medical Equipment')
# (4549, u'C-Family Planning')
# (4550, u'C-Abortions')
# (4551, u'C-Screening Services')
# (4552, u'C-Home Health')
# (4553, u'C-Medicare Payments')
# (4554, u'C-Home And Community')
# (4555, u'C-Hospice')
# (4556, u'C-Medical Transport')
# (4557, u'C-Case Management')
# (4558, u'C-Other Services')
# (4559, u'C-Balance')
# (4560, u'C-Collections')
# (4561, u'C-Total Net')
# (4562, None)
# (4563, u'Washington')
# (4564, None)
# (4565, u'Medical Assistance Program')
# (4566, u'Service Category')
# (4567, None)
# (4568, u'Inpatient Hospital - Reg. Payments')
# (4569, u'Inpatient Hospital - DSH')
# (4570, u'Mental Health Facility Services - Reg. Payments')
# (4571, u'Mental Health Facility - DSH')
# (4572, u'Nursing Facility Services')
# (4573, u'Intermediate Care Facility - Public')
# (4574, u'Intermediate Care - Private')
# (4575, u"Physicians' Services")
# (4576, u'Outpatient Hospital Services')
# (4577, u'Prescribed Drugs')
# (4578, u'Drug Rebate Offset - National')
# (4579, u'Drug Rebate Offset - State Sidebar Agreement')
# (4580, u'Dental Services')
# (4581, u'Other Practicioners')
# (4582, u'Clinic Services')
# (4583, u'Laboratory/Radiological')
# (4584, u'Home Health Services')
# (4585, u'Sterilizations')
# (4586, u'Abortions')
# (4587, u'EPSDT Screening')
# (4588, u'Rural Health')
# (4589, u'Medicare - Part A')
# (4590, u'Medicare - Part B')
# (4591, u'120% - 134% Of Poverty')
# (4592, u'135% - 175% Of Poverty')
# (4593, u'Coinsurance')
# (4594, u'Medicaid - MCO')
# (4595, u'Medicaid - PHP')
# (4596, u'Medicaid - Group Health')
# (4597, u'Medicaid - Coinsurance')
# (4598, u'Medicaid - Other')
# (4599, u'Home and Community')
# (4600, u'Home And Community - Disabled Elderly')
# (4601, u'Community Supported')
# (4602, u'All-Inclusive Care Elderly')
# (4603, u'Personal Care Services')
# (4604, u'Targeted Case Management')
# (4605, u'Primary Care Case Management')
# (4606, u'Hospice Benefits')
# (4607, u'Emergency')
# (4608, u'Federally-Qualified Health Center')
# (4609, u'Other Care Services')
# (4610, u'Balance')
# (4611, u'Collections')
# (4612, u'Total Net Expenditures')
# (4613, u'C-Premiums: Up To 150% - Gross Premiums Paid')
# (4614, u'C-Premiums: Up To 150% - Cost Sharing Offset')
# (4615, u'C-Premiums: Over 150% - Gross Premiums Paid')
# (4616, u'C-Premiums: Over 150% - Cost Sharing Offset')
# (4617, u'C-Inpatient Hospital Services - Reg. Payments')
# (4618, u'C-Inpatient Hospital Services - DSH')
# (4619, u'C-Inpatient Mental Health - Reg. Payment')
# (4620, u'C-Inpatient Mental Health - DSH')
# (4621, u'C-Nursing Care Services')
# (4622, u'C-Physician/Surgical')
# (4623, u'C-Outpatient Hospital Services')
# (4624, u'C-Outpatient Mental Health')
# (4625, u'C-Prescribed Drugs')
# (4626, u'C-Drug Rebate - National')
# (4627, u'C-Drug Rebate - State')
# (4628, u'C-Dental Services')
# (4629, u'C-Vision Sevices')
# (4630, u'C-Other Practitioners')
# (4631, u'C-Clinic Services')
# (4632, u'C-Therapy Services')
# (4633, u'C-Laboratory/Radiological Services')
# (4634, u'C-Medical Equipment')
# (4635, u'C-Family Planning')
# (4636, u'C-Abortions')
# (4637, u'C-Screening Services')
# (4638, u'C-Home Health')
# (4639, u'C-Medicare Payments')
# (4640, u'C-Home And Community')
# (4641, u'C-Hospice')
# (4642, u'C-Medical Transport')
# (4643, u'C-Case Management')
# (4644, u'C-Other Services')
# (4645, u'C-Balance')
# (4646, u'C-Collections')
# (4647, u'C-Total Net')
# (4648, None)
# (4649, u'Wisconsin')
# (4650, None)
# (4651, u'Medical Assistance Program')
# (4652, u'Service Category')
# (4653, None)
# (4654, u'Inpatient Hospital - Reg. Payments')
# (4655, u'Inpatient Hospital - DSH')
# (4656, u'Mental Health Facility Services - Reg. Payments')
# (4657, u'Mental Health Facility - DSH')
# (4658, u'Nursing Facility Services')
# (4659, u'Intermediate Care Facility - Public')
# (4660, u'Intermediate Care - Private')
# (4661, u"Physicians' Services")
# (4662, u'Outpatient Hospital Services')
# (4663, u'Prescribed Drugs')
# (4664, u'Drug Rebate Offset - National')
# (4665, u'Drug Rebate Offset - State Sidebar Agreement')
# (4666, u'Dental Services')
# (4667, u'Other Practicioners')
# (4668, u'Clinic Services')
# (4669, u'Laboratory/Radiological')
# (4670, u'Home Health Services')
# (4671, u'Sterilizations')
# (4672, u'Abortions')
# (4673, u'EPSDT Screening')
# (4674, u'Rural Health')
# (4675, u'Medicare - Part A')
# (4676, u'Medicare - Part B')
# (4677, u'120% - 134% Of Poverty')
# (4678, u'135% - 175% Of Poverty')
# (4679, u'Coinsurance')
# (4680, u'Medicaid - MCO')
# (4681, u'Medicaid - PHP')
# (4682, u'Medicaid - Group Health')
# (4683, u'Medicaid - Coinsurance')
# (4684, u'Medicaid - Other')
# (4685, u'Home and Community')
# (4686, u'Home And Community - Disabled Elderly')
# (4687, u'Community Supported')
# (4688, u'All-Inclusive Care Elderly')
# (4689, u'Personal Care Services')
# (4690, u'Targeted Case Management')
# (4691, u'Primary Care Case Management')
# (4692, u'Hospice Benefits')
# (4693, u'Emergency')
# (4694, u'Federally-Qualified Health Center')
# (4695, u'Other Care Services')
# (4696, u'Balance')
# (4697, u'Collections')
# (4698, u'Total Net Expenditures')
# (4699, u'C-Premiums: Up To 150% - Gross Premiums Paid')
# (4700, u'C-Premiums: Up To 150% - Cost Sharing Offset')
# (4701, u'C-Premiums: Over 150% - Gross Premiums Paid')
# (4702, u'C-Premiums: Over 150% - Cost Sharing Offset')
# (4703, u'C-Inpatient Hospital Services - Reg. Payments')
# (4704, u'C-Inpatient Hospital Services - DSH')
# (4705, u'C-Inpatient Mental Health - Reg. Payment')
# (4706, u'C-Inpatient Mental Health - DSH')
# (4707, u'C-Nursing Care Services')
# (4708, u'C-Physician/Surgical')
# (4709, u'C-Outpatient Hospital Services')
# (4710, u'C-Outpatient Mental Health')
# (4711, u'C-Prescribed Drugs')
# (4712, u'C-Drug Rebate - National')
# (4713, u'C-Drug Rebate - State')
# (4714, u'C-Dental Services')
# (4715, u'C-Vision Sevices')
# (4716, u'C-Other Practitioners')
# (4717, u'C-Clinic Services')
# (4718, u'C-Therapy Services')
# (4719, u'C-Laboratory/Radiological Services')
# (4720, u'C-Medical Equipment')
# (4721, u'C-Family Planning')
# (4722, u'C-Abortions')
# (4723, u'C-Screening Services')
# (4724, u'C-Home Health')
# (4725, u'C-Medicare Payments')
# (4726, u'C-Home And Community')
# (4727, u'C-Hospice')
# (4728, u'C-Medical Transport')
# (4729, u'C-Case Management')
# (4730, u'C-Other Services')
# (4731, u'C-Balance')
# (4732, u'C-Collections')
# (4733, u'C-Total Net')
# (4734, None)
# (4735, u'West Virginia')
# (4736, None)
# (4737, u'Medical Assistance Program')
# (4738, u'Service Category')
# (4739, None)
# (4740, u'Inpatient Hospital - Reg. Payments')
# (4741, u'Inpatient Hospital - DSH')
# (4742, u'Mental Health Facility Services - Reg. Payments')
# (4743, u'Mental Health Facility - DSH')
# (4744, u'Nursing Facility Services')
# (4745, u'Intermediate Care Facility - Public')
# (4746, u'Intermediate Care - Private')
# (4747, u"Physicians' Services")
# (4748, u'Outpatient Hospital Services')
# (4749, u'Prescribed Drugs')
# (4750, u'Drug Rebate Offset - National')
# (4751, u'Drug Rebate Offset - State Sidebar Agreement')
# (4752, u'Dental Services')
# (4753, u'Other Practicioners')
# (4754, u'Clinic Services')
# (4755, u'Laboratory/Radiological')
# (4756, u'Home Health Services')
# (4757, u'Sterilizations')
# (4758, u'Abortions')
# (4759, u'EPSDT Screening')
# (4760, u'Rural Health')
# (4761, u'Medicare - Part A')
# (4762, u'Medicare - Part B')
# (4763, u'120% - 134% Of Poverty')
# (4764, u'135% - 175% Of Poverty')
# (4765, u'Coinsurance')
# (4766, u'Medicaid - MCO')
# (4767, u'Medicaid - PHP')
# (4768, u'Medicaid - Group Health')
# (4769, u'Medicaid - Coinsurance')
# (4770, u'Medicaid - Other')
# (4771, u'Home and Community')
# (4772, u'Home And Community - Disabled Elderly')
# (4773, u'Community Supported')
# (4774, u'All-Inclusive Care Elderly')
# (4775, u'Personal Care Services')
# (4776, u'Targeted Case Management')
# (4777, u'Primary Care Case Management')
# (4778, u'Hospice Benefits')
# (4779, u'Emergency')
# (4780, u'Federally-Qualified Health Center')
# (4781, u'Other Care Services')
# (4782, u'Balance')
# (4783, u'Collections')
# (4784, u'Total Net Expenditures')
# (4785, u'C-Premiums: Up To 150% - Gross Premiums Paid')
# (4786, u'C-Premiums: Up To 150% - Cost Sharing Offset')
# (4787, u'C-Premiums: Over 150% - Gross Premiums Paid')
# (4788, u'C-Premiums: Over 150% - Cost Sharing Offset')
# (4789, u'C-Inpatient Hospital Services - Reg. Payments')
# (4790, u'C-Inpatient Hospital Services - DSH')
# (4791, u'C-Inpatient Mental Health - Reg. Payment')
# (4792, u'C-Inpatient Mental Health - DSH')
# (4793, u'C-Nursing Care Services')
# (4794, u'C-Physician/Surgical')
# (4795, u'C-Outpatient Hospital Services')
# (4796, u'C-Outpatient Mental Health')
# (4797, u'C-Prescribed Drugs')
# (4798, u'C-Drug Rebate - National')
# (4799, u'C-Drug Rebate - State')
# (4800, u'C-Dental Services')
# (4801, u'C-Vision Sevices')
# (4802, u'C-Other Practitioners')
# (4803, u'C-Clinic Services')
# (4804, u'C-Therapy Services')
# (4805, u'C-Laboratory/Radiological Services')
# (4806, u'C-Medical Equipment')
# (4807, u'C-Family Planning')
# (4808, u'C-Abortions')
# (4809, u'C-Screening Services')
# (4810, u'C-Home Health')
# (4811, u'C-Medicare Payments')
# (4812, u'C-Home And Community')
# (4813, u'C-Hospice')
# (4814, u'C-Medical Transport')
# (4815, u'C-Case Management')
# (4816, u'C-Other Services')
# (4817, u'C-Balance')
# (4818, u'C-Collections')
# (4819, u'C-Total Net')
# (4820, None)
# (4821, u'Wyoming')
# (4822, None)
# (4823, u'Medical Assistance Program')
# (4824, u'Service Category')
# (4825, None)
# (4826, u'Inpatient Hospital - Reg. Payments')
# (4827, u'Inpatient Hospital - DSH')
# (4828, u'Mental Health Facility Services - Reg. Payments')
# (4829, u'Mental Health Facility - DSH')
# (4830, u'Nursing Facility Services')
# (4831, u'Intermediate Care Facility - Public')
# (4832, u'Intermediate Care - Private')
# (4833, u"Physicians' Services")
# (4834, u'Outpatient Hospital Services')
# (4835, u'Prescribed Drugs')
# (4836, u'Drug Rebate Offset - National')
# (4837, u'Drug Rebate Offset - State Sidebar Agreement')
# (4838, u'Dental Services')
# (4839, u'Other Practicioners')
# (4840, u'Clinic Services')
# (4841, u'Laboratory/Radiological')
# (4842, u'Home Health Services')
# (4843, u'Sterilizations')
# (4844, u'Abortions')
# (4845, u'EPSDT Screening')
# (4846, u'Rural Health')
# (4847, u'Medicare - Part A')
# (4848, u'Medicare - Part B')
# (4849, u'120% - 134% Of Poverty')
# (4850, u'135% - 175% Of Poverty')
# (4851, u'Coinsurance')
# (4852, u'Medicaid - MCO')
# (4853, u'Medicaid - PHP')
# (4854, u'Medicaid - Group Health')
# (4855, u'Medicaid - Coinsurance')
# (4856, u'Medicaid - Other')
# (4857, u'Home and Community')
# (4858, u'Home And Community - Disabled Elderly')
# (4859, u'Community Supported')
# (4860, u'All-Inclusive Care Elderly')
# (4861, u'Personal Care Services')
# (4862, u'Targeted Case Management')
# (4863, u'Primary Care Case Management')
# (4864, u'Hospice Benefits')
# (4865, u'Emergency')
# (4866, u'Federally-Qualified Health Center')
# (4867, u'Other Care Services')
# (4868, u'Balance')
# (4869, u'Collections')
# (4870, u'Total Net Expenditures')
# (4871, u'C-Premiums: Up To 150% - Gross Premiums Paid')
# (4872, u'C-Premiums: Up To 150% - Cost Sharing Offset')
# (4873, u'C-Premiums: Over 150% - Gross Premiums Paid')
# (4874, u'C-Premiums: Over 150% - Cost Sharing Offset')
# (4875, u'C-Inpatient Hospital Services - Reg. Payments')
# (4876, u'C-Inpatient Hospital Services - DSH')
# (4877, u'C-Inpatient Mental Health - Reg. Payment')
# (4878, u'C-Inpatient Mental Health - DSH')
# (4879, u'C-Nursing Care Services')
# (4880, u'C-Physician/Surgical')
# (4881, u'C-Outpatient Hospital Services')
# (4882, u'C-Outpatient Mental Health')
# (4883, u'C-Prescribed Drugs')
# (4884, u'C-Drug Rebate - National')
# (4885, u'C-Drug Rebate - State')
# (4886, u'C-Dental Services')
# (4887, u'C-Vision Sevices')
# (4888, u'C-Other Practitioners')
# (4889, u'C-Clinic Services')
# (4890, u'C-Therapy Services')
# (4891, u'C-Laboratory/Radiological Services')
# (4892, u'C-Medical Equipment')
# (4893, u'C-Family Planning')
# (4894, u'C-Abortions')
# (4895, u'C-Screening Services')
# (4896, u'C-Home Health')
# (4897, u'C-Medicare Payments')
# (4898, u'C-Home And Community')
# (4899, u'C-Hospice')
# (4900, u'C-Medical Transport')
# (4901, u'C-Case Management')
# (4902, u'C-Other Services')
# (4903, u'C-Balance')
# (4904, u'C-Collections')
# (4905, u'C-Total Net')
# (4906, None)
# (4907, u'National Totals')
# (4908, None)
# (4909, u'Medical Assistance Program')
# (4910, u'Service Category')
# (4911, None)
# (4912, u'Inpatient Hospital - Reg. Payments')
# (4913, u'Inpatient Hospital - DSH')
# (4914, u'Mental Health Facility Services - Reg. Payments')
# (4915, u'Mental Health Facility - DSH')
# (4916, u'Nursing Facility Services')
# (4917, u'Intermediate Care Facility - Public')
# (4918, u'Intermediate Care - Private')
# (4919, u"Physicians' Services")
# (4920, u'Outpatient Hospital Services')
# (4921, u'Prescribed Drugs')
# (4922, u'Drug Rebate Offset - National')
# (4923, u'Drug Rebate Offset - State Sidebar Agreement')
# (4924, u'Dental Services')
# (4925, u'Other Practicioners')
# (4926, u'Clinic Services')
# (4927, u'Laboratory/Radiological')
# (4928, u'Home Health Services')
# (4929, u'Sterilizations')
# (4930, u'Abortions')
# (4931, u'EPSDT Screening')
# (4932, u'Rural Health')
# (4933, u'Medicare - Part A')
# (4934, u'Medicare - Part B')
# (4935, u'120% - 134% Of Poverty')
# (4936, u'135% - 175% Of Poverty')
# (4937, u'Coinsurance')
# (4938, u'Medicaid - MCO')
# (4939, u'Medicaid - PHP')
# (4940, u'Medicaid - Group Health')
# (4941, u'Medicaid - Coinsurance')
# (4942, u'Medicaid - Other')
# (4943, u'Home and Community')
# (4944, u'Home And Community - Disabled Elderly')
# (4945, u'Community Supported')
# (4946, u'All-Inclusive Care Elderly')
# (4947, u'Personal Care Services')
# (4948, u'Targeted Case Management')
# (4949, u'Primary Care Case Management')
# (4950, u'Hospice Benefits')
# (4951, u'Emergency')
# (4952, u'Federally-Qualified Health Center')
# (4953, u'Other Care Services')
# (4954, u'Balance')
# (4955, u'Collections')
# (4956, u'Total Net Expenditures')
# (4957, u'C-Premiums: Up To 150% - Gross Premiums Paid')
# (4958, u'C-Premiums: Up To 150% - Cost Sharing Offset')
# (4959, u'C-Premiums: Over 150% - Gross Premiums Paid')
# (4960, u'C-Premiums: Over 150% - Cost Sharing Offset')
# (4961, u'C-Inpatient Hospital Services - Reg. Payments')
# (4962, u'C-Inpatient Hospital Services - DSH')
# (4963, u'C-Inpatient Mental Health - Reg. Payment')
# (4964, u'C-Inpatient Mental Health - DSH')
# (4965, u'C-Nursing Care Services')
# (4966, u'C-Physician/Surgical')
# (4967, u'C-Outpatient Hospital Services')
# (4968, u'C-Outpatient Mental Health')
# (4969, u'C-Prescribed Drugs')
# (4970, u'C-Drug Rebate - National')
# (4971, u'C-Drug Rebate - State')
# (4972, u'C-Dental Services')
# (4973, u'C-Vision Sevices')
# (4974, u'C-Other Practitioners')
# (4975, u'C-Clinic Services')
# (4976, u'C-Therapy Services')
# (4977, u'C-Laboratory/Radiological Services')
# (4978, u'C-Medical Equipment')
# (4979, u'C-Family Planning')
# (4980, u'C-Abortions')
# (4981, u'C-Screening Services')
# (4982, u'C-Home Health')
# (4983, u'C-Medicare Payments')
# (4984, u'C-Home And Community')
# (4985, u'C-Hospice')
# (4986, u'C-Medical Transport')
# (4987, u'C-Case Management')
# (4988, u'C-Other Services')
# (4989, u'C-Balance')
# (4990, u'C-Collections')
# (4991, u'C-Total Net')

# %%
dir(fmr97_dict[1998])
# Out:
# ['BREAK_COLUMN',
#  'BREAK_NONE',
#  'BREAK_ROW',
#  'ORIENTATION_LANDSCAPE',
#  'ORIENTATION_PORTRAIT',
#  'PAPERSIZE_A3',
#  'PAPERSIZE_A4',
#  'PAPERSIZE_A4_SMALL',
#  'PAPERSIZE_A5',
#  'PAPERSIZE_EXECUTIVE',
#  'PAPERSIZE_LEDGER',
#  'PAPERSIZE_LEGAL',
#  'PAPERSIZE_LETTER',
#  'PAPERSIZE_LETTER_SMALL',
#  'PAPERSIZE_STATEMENT',
#  'PAPERSIZE_TABLOID',
#  'SHEETSTATE_HIDDEN',
#  'SHEETSTATE_VERYHIDDEN',
#  'SHEETSTATE_VISIBLE',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__doc__',
#  '__format__',
#  '__getattribute__',
#  '__getitem__',
#  '__hash__',
#  '__init__',
#  '__module__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_add_cell',
#  '_auto_filter',
#  '_cells',
#  '_charts',
#  '_comment_count',
#  '_create_relationship',
#  '_data_validations',
#  '_freeze_panes',
#  '_garbage_collect',
#  '_get_cell',
#  '_images',
#  '_invalid_row',
#  '_merged_cells',
#  '_new_cell',
#  '_parent',
#  '_styles',
#  '_title',
#  '_unique_sheet_name',
#  'active_cell',
#  'add_chart',
#  'add_data_validation',
#  'add_drawing',
#  'add_image',
#  'add_print_title',
#  'add_rel',
#  'append',
#  'auto_filter',
#  'bad_title_char_re',
#  'calculate_dimension',
#  'cell',
#  'column_dimensions',
#  'columns',
#  'conditional_formatting',
#  'create_relationship',
#  'default_column_dimension',
#  'default_row_dimension',
#  'dimensions',
#  'encoding',
#  'formula_attributes',
#  'freeze_panes',
#  'garbage_collect',
#  'get_cell_collection',
#  'get_highest_column',
#  'get_highest_row',
#  'get_named_range',
#  'get_squared_range',
#  'get_style',
#  'header_footer',
#  'iter_rows',
#  'max_column',
#  'max_row',
#  'merge_cells',
#  'merged_cell_ranges',
#  'merged_cells',
#  'min_col',
#  'min_row',
#  'orientation',
#  'page_breaks',
#  'page_margins',
#  'page_setup',
#  'paper_size',
#  'parent',
#  'point_pos',
#  'print_options',
#  'protection',
#  'range',
#  'relationships',
#  'repr_format',
#  'row_dimensions',
#  'rows',
#  'selected_cell',
#  'set_printer_settings',
#  'set_style',
#  'sheet_properties',
#  'sheet_state',
#  'sheet_view',
#  'show_gridlines',
#  'show_summary_below',
#  'show_summary_right',
#  'title',
#  'unique_sheet_name',
#  'unmerge_cells',
#  'vba_code',
#  'vba_controls']

# %%
dir(fmr97)
# Out:
# ['_Workbook__read_only',
#  '_Workbook__thread_local_data',
#  '_Workbook__write_only',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__doc__',
#  '__format__',
#  '__getattribute__',
#  '__getitem__',
#  '__hash__',
#  '__init__',
#  '__iter__',
#  '__module__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_active_sheet_index',
#  '_add_sheet',
#  '_alignments',
#  '_borders',
#  '_cell_styles',
#  '_colors',
#  '_differential_styles',
#  '_external_links',
#  '_fills',
#  '_fonts',
#  '_guess_types',
#  '_local_data',
#  '_named_ranges',
#  '_number_formats',
#  '_optimized_worksheet_class',
#  '_protections',
#  '_read_workbook_settings',
#  '_setup_styles',
#  '_worksheet_class',
#  'active',
#  'add_named_range',
#  'add_sheet',
#  'code_name',
#  'cond_styles',
#  'create_named_range',
#  'create_sheet',
#  'data_only',
#  'drawings',
#  'encoding',
#  'excel_base_date',
#  'get_active_sheet',
#  'get_index',
#  'get_named_range',
#  'get_named_ranges',
#  'get_sheet_by_name',
#  'get_sheet_names',
#  'is_template',
#  'loaded_theme',
#  'properties',
#  'read_only',
#  'read_workbook_settings',
#  'relationships',
#  'remove_named_range',
#  'remove_sheet',
#  'save',
#  'security',
#  'shared_strings',
#  'shared_styles',
#  'sheetnames',
#  'style',
#  'vba_archive',
#  'worksheets',
#  'write_only']
